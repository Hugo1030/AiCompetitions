# %%
import pandas as pd
import numpy as np

# %%
df_pant1 = pd.read_csv('./result/{}_0419_InceptionResNetV2.csv'.format('pant'), header=None) # InceptionResNetV2切分训练集
df_pant2 = pd.read_csv('./result/{}_0419Xception_alldata.csv'.format('pant'), header=None) # xception全训练集

df_lapel1 = pd.read_csv('./result/{}_0419_InceptionResNetV2.csv'.format('lapel'), header=None) # InceptionResNetV2切分训练集
df_lapel2 = pd.read_csv('./result/{}_0419Xception_alldata.csv'.format('lapel'), header=None) # xception全训练集

# %%
# 给分类别增添表头
df_pant1.columns = ['image_id', 'class', 'result']
df_pant2.columns = ['image_id', 'class', 'result']

df_lapel1.columns = ['image_id', 'class', 'result']
df_lapel2.columns = ['image_id', 'class', 'result']

# %%
df_lapel2
# Out:
#                                                image_id                class  \
# 0     Images/lapel_design_labels/518bcadaa97418d29c7...  lapel_design_labels
# 1     Images/lapel_design_labels/156228a4743bfd86cef...  lapel_design_labels
# 2     Images/lapel_design_labels/393f4962b5c2fbf42cb...  lapel_design_labels
# 3     Images/lapel_design_labels/b5074c1b96f2402bab1...  lapel_design_labels
# 4     Images/lapel_design_labels/5ce450fa7e3f1890cb0...  lapel_design_labels
# 5     Images/lapel_design_labels/66efa47c0f9c52b0e25...  lapel_design_labels
# 6     Images/lapel_design_labels/c990e13da9994a5b36c...  lapel_design_labels
# 7     Images/lapel_design_labels/4b5e025898b9f96a859...  lapel_design_labels
# 8     Images/lapel_design_labels/0e22be5ada33f0256db...  lapel_design_labels
# 9     Images/lapel_design_labels/e4dc84373501aa4ba62...  lapel_design_labels
# 10    Images/lapel_design_labels/2abd938226fc7621ba6...  lapel_design_labels
# ...

# %%
def avg_result(label1, label2):
    lst1 = []
    for i in label1['result'].values:
        lst = i.split(';')
        lst1.append(lst)
        
    lst2 = []
    for i in label2['result'].values:
        lst = i.split(';')
        lst2.append(lst)
        
    m = len(lst1)
    n = len(lst1[0])
    
    result = []

    for i in range(m):
        tmp_result = ''
        for j in range(n):
            avg = ((float(lst1[i][j]) + float(lst2[i][j]))/2)
            tmp_result += '{:.4f};'.format(avg)
        result.append(tmp_result[:-1])
    return result

# %%
pant_avg = avg_result(df_pant1, df_pant2)
lapel_avg = avg_result(df_lapel1, df_lapel2)

# %%
df_pant1['result'] = pant_avg
df_lapel1['result'] = lapel_avg

# %%
df_pant1.to_csv('./result/{}_0419a.csv'.format('pant'), header=None, index=False)
df_lapel1.to_csv('./result/{}_0419a.csv'.format('lapel'), header=None, index=False)
