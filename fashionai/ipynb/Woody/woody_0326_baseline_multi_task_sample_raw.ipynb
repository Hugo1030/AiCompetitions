# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 思路
# - 将全部类型的数据分别加载100条
# - 将这些数据对应的图片分别取出，放入不同的文件夹，文件夹命名和之前的文件命名一样
# - 将这些数据和成新label.csv

# %%
df_train = pd.read_csv('label.csv', header=None)
df_train.columns = ['image_id', 'class', 'label']
df_train.head()
# Out:
#                                             image_id                 class  \
# 0  Images/collar_design_labels/4d8a38b29930a403e5...  collar_design_labels
# 1  Images/collar_design_labels/bd0981f231180d2b00...  collar_design_labels
# 2  Images/collar_design_labels/26937e1724feadfe39...  collar_design_labels
# 3  Images/collar_design_labels/cf4140ec542887270f...  collar_design_labels
# 4  Images/collar_design_labels/50644b2b9de045f2d1...  collar_design_labels
#
#    label
# 0  nnynn
# 1  nynnn
# 2  ynnnn
# 3  nynnn
# 4  nynnn

# %%
classes = ['collar_design_labels', 'neckline_design_labels', 'skirt_length_labels', 
            'sleeve_length_labels', 'neck_design_labels', 'coat_length_labels', 'lapel_design_labels', 
            'pant_length_labels']
len(classes)
# Out:
# 8

# %% [markdown]
# ### 将全部类型的数据分别加载100条

# %%
label_small_all=[]
for i in range(len(classes)):
    cur_class=classes[i]
    df_load = df_train[(df_train['class'] == cur_class)][:100]
    label_small_all.append(df_load)

# %%
mkdir sample

# %%
cd sample
# Out:
# /Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes/sample

# %%
mkdir Images

# %%
cd Images
# Out:
# /Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes/sample/Images

# %% [markdown]
# ### 将这些数据对应的图片分别取出，放入不同的文件夹，文件夹命名和之前的文件命名一样

# %%
#批量创建文件夹
import os,sys
for j in classes:
    file_name = j
    os.mkdir(file_name)

# %%
ls
# Out:
# coat_length_labels/     neck_design_labels/     skirt_length_labels/
# collar_design_labels/   neckline_design_labels/ sleeve_length_labels/
# lapel_design_labels/    pant_length_labels/

# %%
pwd
# Out:
# '/Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes/sample/Images'

# %%
cd ../..
# Out:
# /Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes

# %%
ls
# Out:
# FashionAI_text/
# LiChuan0319_transfer_learning_coat.ipynb
# LiChuan0319_transfer_learning_neck.ipynb
# base/
# baseline.ipynb
# baseline_coat.ipynb
# baseline_coat_study.ipynb
# baseline_lapel.ipynb
# baseline_multi_task.ipynb
# baseline_multi_task_sample.ipynb
# baseline_neck.ipynb
# baseline_pant.ipynb
# coat2_weights.h5
# coat_test1_weights.h5
# coat_test2_weights.h5
# coat_test_weights.h5
# fashionAI_attributes_test_a_20180222.tar
# fashionAI_attributes_train_20180222.tar
# files_md5_20180227.txt
# label.csv
# lapel_weights.h5
# neck_weights.h5
# pant_weights.h5
# rank/
# result/
# sample/
# study_doc/
# warm_up_train_20180201.tar
# web/

# %%
ls base/Images
# Out:
# coat_length_labels/         neckline_design_labels/
# coat_length_labels.tar      neckline_design_labels.tar
# collar_design_labels/       pant_length_labels/
# collar_design_labels.tar    pant_length_labels.tar
# lapel_design_labels/        skirt_length_labels/
# lapel_design_labels.tar     skirt_length_labels.tar
# neck_design_labels/         sleeve_length_labels/
# neck_design_labels.tar      sleeve_length_labels.tar

# %%
pwd
# Out:
# '/Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes'

# %%
import shutil

# %%
#移动文件
source_dir='/Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes/base/'
target_dir='/Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes/sample/Images/'
for i in range(len(classes)):
    new_dir=target_dir+str(classes[i])
    for j in label_small_all[i].image_id:
        source_files=os.path.join(source_dir+str(j))
        shutil.move(source_files,new_dir)#shutil.move("oldpos","newpos")  # 移动文件或目录

# %%
cd sample
# Out:
# /Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes/sample

# %%
ls Images/coat_length_labels
# Out:
# 068048ddc6f27374afbc2f62156bb618.jpg  9929c843c50ecfe1c733b3591a3a6c8b.jpg
# 0b3de63486a6d9e576a04c802dbec1a3.jpg  997a91ceb1a64d041001e0822675e3c3.jpg
# 0b9613559f6c0bc193935f1be272787d.jpg  998831e036698d8b3e22923f434fd06b.jpg
# 0dce320c4bf605073995343a743ade93.jpg  a0cff33449a96fe00bb362086149355d.jpg
# 0e73df82f241f6d2aa52affae9822465.jpg  a32e55b2b2c946f3aede14a725e4cc2f.jpg
# 0f1a9fb61911576cf3d801b76a0d90c6.jpg  a682232e4f408a48942b99ee959e09bb.jpg
# 117e5be65c68a2f8356e24e0fb0cae4a.jpg  abbbd60b42b7c28c5dcb0f1e3d205964.jpg
# 1394923ee1bd9c53ba5de827ff5f02e8.jpg  abe32e0db77520dbd08648346c272453.jpg
# 13c89d43fec889cf752a4b5566270e37.jpg  ae316bca8377695d10bad4066567085d.jpg
# 184ec37fbd4d06eb7aa502990efc878c.jpg  b0408fd63bd4f5ce80084d8889c8216e.jpg
# 1b4e7e31ddb54e944764764744038945.jpg  b10f1a21dd81e2e3352a8bb990af4c16.jpg
# 1cab958cad054c4a6c53daea0282b7a3.jpg  b1661a511cfab6f70ecba92be5b8fe1f.jpg
# 1ffd6f6c642f7fdf10a3943fe873a673.jpg  b1978964d9b394b372f14461434583ef.jpg
# 2242b7c41d96c1fe58fda5e3e6889061.jpg  b276c63edc8972cc0ff625578c7db0bb.jpg
# 2352a3d4e1e63d9d251d87c58c0ec7fb.jpg  b43c2867d1eb56f017023be5eb20e9e2.jpg
# 2662ec44068eddeef8a21d7dfedd7415.jpg  b679b0cc4a357935006ddcdaa7791c2e.jpg
# 28c19721de7d3450a533ae49db902098.jpg  b81b085bcc520c5c0df0180e3929fee1.jpg
# 2ee7ffab64fbe15fe8d32273edab79e3.jpg  b9c3ece777dc88c8cf023fb59227150a.jpg
# 3038121a49673ec1e674f7eaa1968775.jpg  bc4ddb02b9287d35b17ca1dcc05d51e9.jpg
# 33f417cca22f77e788d33b0b167f3740.jpg  be77a172b79e37efe95ff2dfb9359b97.jpg
# 3415e3f842c4f7a0e940912677b229b0.jpg  ca95265286e1e34589748c7209b16e0c.jpg
# 3427ca0a7de40bf1f3662474079f8ea6.jpg  ce962d392457625b29626f53d28974e4.jpg
# 3a656ef89b2b369b93049d7250e2b749.jpg  d09e3ae9661d28f0e306f1aeec5a203c.jpg
# 3ac37c77c9b3e8f5177d268f4b61d5e8.jpg  d1176170aa7f2e6e06135c7373cab201.jpg
# 3d2e5af629bb600af39b8ac54d129ea1.jpg  d3d33c73c42010f632ae398be09c2f7a.jpg
# 45f3a47023cbf64d16e09bdb80a29be8.jpg  d5f549691c806d2eaaca0894e6b550e9.jpg
# 4c43a1d625952b3e4f104431801a07ed.jpg  d652ec2f3061d315c0616dba8ad6e9d8.jpg
# 4cb2f822721a48b068272db332f61750.jpg  dd6afdf0b865d69e56d1baf5519e3fac.jpg
# 4ce601daefecba41fdda45513eec6e2e.jpg  dde0cec42f966a5f3e450401e926604d.jpg
# 4e75415fe029c5fd4488c73bb1a15cdd.jpg  ddeadc5f4a552a6a219f176a9cca1528.jpg
# 50718b6871ba880d0c40420bb6007f9a.jpg  de6bd527fcdf9d9ec57328573192e4c8.jpg
# 55e575249333279292a86d36ce7d3498.jpg  df38661a21d592e644eff6c67ed7ab4d.jpg
# 578064ebfab24ca9c2020d7415f8b411.jpg  df5fb8909eb23a2f7c3530e12d7669c8.jpg
# 5851dab85bdd449307c0331f4e6d569f.jpg  df75736f29cd502aaa6a9ecceb616b2e.jpg
# 5ca46ec4ddd6ae6873f87e62a299d2f2.jpg  e2377fcae36b942d3ea5be83cf7fe342.jpg
# 65da797bb4c9c1e9dc9cbdc50c24c5fb.jpg  e2e09e65819c5caf2ebd34d38e45b957.jpg
# 666fdec1312e1b2de5a144b595552678.jpg  e4bee622ce02c51dd5e34adb50a9e3f4.jpg
# 69e1e41ca74c95fce96fed9440ff7747.jpg  e5ab251112324d0e95fd33f0824b047a.jpg
# 6fb17bcd271099cd09cbf534220f624c.jpg  e6564b07807ad8490a2d591aa91b6552.jpg
# 6ff9038651aafdc67554e8f32d71da48.jpg  e89d4fa789419727fed4ee19b776e6b1.jpg
# 7a3bc1ca315b710f1a477d0d050e8716.jpg  ea667d581a59bec71f071619211e475d.jpg
# 7f6e0d60fc67fb747eb8a803453d2206.jpg  ec0aa82dd3ba5382dc6435ed19efad1a.jpg
# 883996c9d45ccbe6c2d09aca08a92302.jpg  ed76baa617eb4a364378745b0d8341e9.jpg
# 8d1a1226d6c485a15e0d7d4cb515560b.jpg  f1959e596f6785684fc1c9aa0e3760fa.jpg
# 8e0db295742654e560e911a978fd3be4.jpg  f4335fe694f984344bed374e2b310676.jpg
# 8e979ae51cd45cd281b70c708bcdfca5.jpg  f50523f923d5aecef03a9e1e5069366f.jpg
# 91bb3fe281fda146d71fb54d465378ce.jpg  fc1bcce0ac32c63601105c7dd503a61b.jpg
# 9219fb0b599c98291784eb94223ae909.jpg  fc5b861a5b629dc96d01d16710623e09.jpg
# 967c96c64a2e734198addb7adec50d17.jpg  fcf92b78dab3c7d9a610bf68281885e1.jpg
# 97a09b362b9cc7a6e53c86317e09c62e.jpg  ff777f3cffd9f47b8c7c38e2b825c0b3.jpg

# %% [markdown]
# ### 将这些数据和成新label.csv

# %%
cd ../..
# Out:
# /Users/suncan/Downloads/Kaggle/tianchi_other_file

# %%
ls
# Out:
# FashionAI_Attributes/
# FashionAI全球挑战赛—服饰关键点定位/
# Keras-Demo/
# MC-data-space.pdf
# MTL_sample.ipynb
# NCES_table_design.pdf
# ODPS最新SQL参考手册.pdf
# keras-image-data-augmentation/
# 盐城销量预测/
# 天池用户手册_数加平台.docx

# %%
cd FashionAI_Attributes
# Out:
# /Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes

# %%
ls
# Out:
# FashionAI_text/
# LiChuan0319_transfer_learning_coat.ipynb
# LiChuan0319_transfer_learning_neck.ipynb
# base/
# baseline.ipynb
# baseline_coat.ipynb
# baseline_coat_study.ipynb
# baseline_lapel.ipynb
# baseline_multi_task.ipynb
# baseline_multi_task_sample.ipynb
# baseline_neck.ipynb
# baseline_pant.ipynb
# coat2_weights.h5
# coat_test1_weights.h5
# coat_test2_weights.h5
# coat_test_weights.h5
# fashionAI_attributes_test_a_20180222.tar
# fashionAI_attributes_train_20180222.tar
# files_md5_20180227.txt
# label.csv
# lapel_weights.h5
# neck_weights.h5
# pant_weights.h5
# rank/
# result/
# sample/
# study_doc/
# warm_up_train_20180201.tar
# web/

# %%
cd sample
# Out:
# /Users/suncan/Downloads/Kaggle/tianchi_other_file/FashionAI_Attributes/sample

# %%
ss=''
for i in range(len(label_small_all)):
    ss +='label_small_all[%s],'%i
ss
# Out:
# 'label_small_all[0],label_small_all[1],label_small_all[2],label_small_all[3],label_small_all[4],label_small_all[5],label_small_all[6],label_small_all[7],'

# %%
pd_all=pd.concat([label_small_all[0],label_small_all[1],label_small_all[2],label_small_all[3],label_small_all[4],label_small_all[5],label_small_all[6],label_small_all[7]])
pd_all.reset_index(inplace=True)
del pd_all['index']
pd_all
# Out:
#                                               image_id                 class  \
# 0    Images/collar_design_labels/4d8a38b29930a403e5...  collar_design_labels
# 1    Images/collar_design_labels/bd0981f231180d2b00...  collar_design_labels
# 2    Images/collar_design_labels/26937e1724feadfe39...  collar_design_labels
# 3    Images/collar_design_labels/cf4140ec542887270f...  collar_design_labels
# 4    Images/collar_design_labels/50644b2b9de045f2d1...  collar_design_labels
# 5    Images/collar_design_labels/fd01ac6593f254a5dd...  collar_design_labels
# 6    Images/collar_design_labels/65ed12f3e20636c885...  collar_design_labels
# 7    Images/collar_design_labels/dd9f87d4474767d42e...  collar_design_labels
# 8    Images/collar_design_labels/133cb2de8d5456c4a7...  collar_design_labels
# 9    Images/collar_design_labels/fcbe592d662a9a5355...  collar_design_labels
# 10   Images/collar_design_labels/c4ca44b968580ce72d...  collar_design_labels
# 11   Images/collar_design_labels/025622f59a6ea90e87...  collar_design_labels
# 12   Images/collar_design_labels/a04d5e69d76a3ca6e3...  collar_design_labels
# 13   Images/collar_design_labels/3ead6a57d4d5042ce3...  collar_design_labels
# 14   Images/collar_design_labels/6d6d15d65356e3eda6...  collar_design_labels
# 15   Images/collar_design_labels/c62d78f4065e6823f2...  collar_design_labels
# 16   Images/collar_design_labels/fc1d058d59cda62eb9...  collar_design_labels
# 17   Images/collar_design_labels/ddb4a961691e31df9b...  collar_design_labels
# 18   Images/collar_design_labels/3e14d9f7d8400769d6...  collar_design_labels
# 19   Images/collar_design_labels/e375a7f37793709ffa...  collar_design_labels
# 20   Images/collar_design_labels/96d5b3a319eb83cd93...  collar_design_labels
# 21   Images/collar_design_labels/dbd6db08717a98c9ba...  collar_design_labels
# 22   Images/collar_design_labels/2f639f11de22076ead...  collar_design_labels
# 23   Images/collar_design_labels/04a001a353a1ab5b90...  collar_design_labels
# 24   Images/collar_design_labels/6f15f8fdfa9538bc67...  collar_design_labels
# 25   Images/collar_design_labels/8391a019ed5f768229...  collar_design_labels
# 26   Images/collar_design_labels/226bb60f471640c1d1...  collar_design_labels
# 27   Images/collar_design_labels/836e57602943669f24...  collar_design_labels
# 28   Images/collar_design_labels/6da096fdf68ff7636c...  collar_design_labels
# 29   Images/collar_design_labels/fd6760054d40adc3f2...  collar_design_labels
# ..                                                 ...                   ...
# 770  Images/pant_length_labels/c248b0e656c251126dd1...    pant_length_labels
# 771  Images/pant_length_labels/1a0ec1f234b8d22438fd...    pant_length_labels
# 772  Images/pant_length_labels/faa5daabc564f4daee1d...    pant_length_labels
# 773  Images/pant_length_labels/a144ae7d886ab1b9ef63...    pant_length_labels
# 774  Images/pant_length_labels/e470968072ac4b2352d5...    pant_length_labels
# 775  Images/pant_length_labels/6daad428a82c843a679e...    pant_length_labels
# 776  Images/pant_length_labels/65d3c72a9c85e34919a8...    pant_length_labels
# 777  Images/pant_length_labels/2536d7964a1587fc6380...    pant_length_labels
# 778  Images/pant_length_labels/37621834d7379d60265d...    pant_length_labels
# 779  Images/pant_length_labels/a8cf6a5b298d432ef7c4...    pant_length_labels
# 780  Images/pant_length_labels/52508a9cd02954aa4d6f...    pant_length_labels
# 781  Images/pant_length_labels/0135cb1d96db9987293c...    pant_length_labels
# 782  Images/pant_length_labels/7f1e4ac4d253bbbb7ba2...    pant_length_labels
# 783  Images/pant_length_labels/19aaa3b2baaea2e79572...    pant_length_labels
# 784  Images/pant_length_labels/936e7bdfb7cf86ca01e0...    pant_length_labels
# 785  Images/pant_length_labels/b00cb007f4aeb6ea8123...    pant_length_labels
# 786  Images/pant_length_labels/16822a373b304776771d...    pant_length_labels
# 787  Images/pant_length_labels/4daa6984d7a2ff728625...    pant_length_labels
# 788  Images/pant_length_labels/9454b279696f49d5b689...    pant_length_labels
# 789  Images/pant_length_labels/02ce55e5dd053b48fe34...    pant_length_labels
# 790  Images/pant_length_labels/d36d88f348aeddc8a8db...    pant_length_labels
# 791  Images/pant_length_labels/2ce7ffb1d312bba1c246...    pant_length_labels
# 792  Images/pant_length_labels/9712a2ea46f15b4d1589...    pant_length_labels
# 793  Images/pant_length_labels/1360d4777b24ea3f21f9...    pant_length_labels
# 794  Images/pant_length_labels/4021c3cb89712aabf27b...    pant_length_labels
# 795  Images/pant_length_labels/963b92a15241bba91ca8...    pant_length_labels
# 796  Images/pant_length_labels/813d03e0262b7115f7e3...    pant_length_labels
# 797  Images/pant_length_labels/f0f2fc832894801b81c6...    pant_length_labels
# 798  Images/pant_length_labels/dfe61366843ab314d74a...    pant_length_labels
# 799  Images/pant_length_labels/07c7f768076b25e93562...    pant_length_labels
#
#       label
# 0     nnynn
# 1     nynnn
# 2     ynnnn
# 3     nynnn
# 4     nynnn
# 5     ynnnn
# 6     nnynn
# 7     nmynn
# 8     nnnny
# 9     nynnn
# 10    ynnnn
# 11    nynnn
# 12    nnynn
# 13    ynnnn
# 14    nnnyn
# 15    ynnnn
# 16    nnnyn
# 17    nynnn
# 18    nnnyn
# 19    nnynn
# 20    nnnyn
# 21    nnnny
# 22    nnnny
# 23    nnynn
# 24    nnnny
# 25    nnynn
# 26    nnnyn
# 27    nnnny
# 28    ynnnn
# 29    ynnnn
# ..      ...
# 770  nynnnn
# 771  nnnynn
# 772  nnnnny
# 773  nnnynn
# 774  ynnnnn
# 775  nnnnyn
# 776  nnnnny
# 777  ynnnnn
# 778  nynnnn
# 779  ynnnnn
# 780  nnnnny
# 781  nnnynn
# 782  nnynnn
# 783  nnnynn
# 784  ynnnnn
# 785  nynnnn
# 786  nynnnn
# 787  nnynnn
# 788  nynnnn
# 789  nnnnyn
# 790  nnnnny
# 791  nynnnn
# 792  nnnynn
# 793  nynnnn
# 794  nnnnny
# 795  nnnnyn
# 796  nnynnn
# 797  nnynnn
# 798  ynnnnn
# 799  nynnnn
#
# [800 rows x 3 columns]

# %%
pd_all.to_csv('label.csv',index=False)

# %%
ls
# Out:
# Images/    label      label.csv

# %%
pd_test=pd.read_csv('label.csv')
pd_test
# Out:
#                                               image_id                 class  \
# 0    Images/collar_design_labels/4d8a38b29930a403e5...  collar_design_labels
# 1    Images/collar_design_labels/bd0981f231180d2b00...  collar_design_labels
# 2    Images/collar_design_labels/26937e1724feadfe39...  collar_design_labels
# 3    Images/collar_design_labels/cf4140ec542887270f...  collar_design_labels
# 4    Images/collar_design_labels/50644b2b9de045f2d1...  collar_design_labels
# 5    Images/collar_design_labels/fd01ac6593f254a5dd...  collar_design_labels
# 6    Images/collar_design_labels/65ed12f3e20636c885...  collar_design_labels
# 7    Images/collar_design_labels/dd9f87d4474767d42e...  collar_design_labels
# 8    Images/collar_design_labels/133cb2de8d5456c4a7...  collar_design_labels
# 9    Images/collar_design_labels/fcbe592d662a9a5355...  collar_design_labels
# 10   Images/collar_design_labels/c4ca44b968580ce72d...  collar_design_labels
# 11   Images/collar_design_labels/025622f59a6ea90e87...  collar_design_labels
# 12   Images/collar_design_labels/a04d5e69d76a3ca6e3...  collar_design_labels
# 13   Images/collar_design_labels/3ead6a57d4d5042ce3...  collar_design_labels
# 14   Images/collar_design_labels/6d6d15d65356e3eda6...  collar_design_labels
# 15   Images/collar_design_labels/c62d78f4065e6823f2...  collar_design_labels
# 16   Images/collar_design_labels/fc1d058d59cda62eb9...  collar_design_labels
# 17   Images/collar_design_labels/ddb4a961691e31df9b...  collar_design_labels
# 18   Images/collar_design_labels/3e14d9f7d8400769d6...  collar_design_labels
# 19   Images/collar_design_labels/e375a7f37793709ffa...  collar_design_labels
# 20   Images/collar_design_labels/96d5b3a319eb83cd93...  collar_design_labels
# 21   Images/collar_design_labels/dbd6db08717a98c9ba...  collar_design_labels
# 22   Images/collar_design_labels/2f639f11de22076ead...  collar_design_labels
# 23   Images/collar_design_labels/04a001a353a1ab5b90...  collar_design_labels
# 24   Images/collar_design_labels/6f15f8fdfa9538bc67...  collar_design_labels
# 25   Images/collar_design_labels/8391a019ed5f768229...  collar_design_labels
# 26   Images/collar_design_labels/226bb60f471640c1d1...  collar_design_labels
# 27   Images/collar_design_labels/836e57602943669f24...  collar_design_labels
# 28   Images/collar_design_labels/6da096fdf68ff7636c...  collar_design_labels
# 29   Images/collar_design_labels/fd6760054d40adc3f2...  collar_design_labels
# ..                                                 ...                   ...
# 770  Images/pant_length_labels/c248b0e656c251126dd1...    pant_length_labels
# 771  Images/pant_length_labels/1a0ec1f234b8d22438fd...    pant_length_labels
# 772  Images/pant_length_labels/faa5daabc564f4daee1d...    pant_length_labels
# 773  Images/pant_length_labels/a144ae7d886ab1b9ef63...    pant_length_labels
# 774  Images/pant_length_labels/e470968072ac4b2352d5...    pant_length_labels
# 775  Images/pant_length_labels/6daad428a82c843a679e...    pant_length_labels
# 776  Images/pant_length_labels/65d3c72a9c85e34919a8...    pant_length_labels
# 777  Images/pant_length_labels/2536d7964a1587fc6380...    pant_length_labels
# 778  Images/pant_length_labels/37621834d7379d60265d...    pant_length_labels
# 779  Images/pant_length_labels/a8cf6a5b298d432ef7c4...    pant_length_labels
# 780  Images/pant_length_labels/52508a9cd02954aa4d6f...    pant_length_labels
# 781  Images/pant_length_labels/0135cb1d96db9987293c...    pant_length_labels
# 782  Images/pant_length_labels/7f1e4ac4d253bbbb7ba2...    pant_length_labels
# 783  Images/pant_length_labels/19aaa3b2baaea2e79572...    pant_length_labels
# 784  Images/pant_length_labels/936e7bdfb7cf86ca01e0...    pant_length_labels
# 785  Images/pant_length_labels/b00cb007f4aeb6ea8123...    pant_length_labels
# 786  Images/pant_length_labels/16822a373b304776771d...    pant_length_labels
# 787  Images/pant_length_labels/4daa6984d7a2ff728625...    pant_length_labels
# 788  Images/pant_length_labels/9454b279696f49d5b689...    pant_length_labels
# 789  Images/pant_length_labels/02ce55e5dd053b48fe34...    pant_length_labels
# 790  Images/pant_length_labels/d36d88f348aeddc8a8db...    pant_length_labels
# 791  Images/pant_length_labels/2ce7ffb1d312bba1c246...    pant_length_labels
# 792  Images/pant_length_labels/9712a2ea46f15b4d1589...    pant_length_labels
# 793  Images/pant_length_labels/1360d4777b24ea3f21f9...    pant_length_labels
# 794  Images/pant_length_labels/4021c3cb89712aabf27b...    pant_length_labels
# 795  Images/pant_length_labels/963b92a15241bba91ca8...    pant_length_labels
# 796  Images/pant_length_labels/813d03e0262b7115f7e3...    pant_length_labels
# 797  Images/pant_length_labels/f0f2fc832894801b81c6...    pant_length_labels
# 798  Images/pant_length_labels/dfe61366843ab314d74a...    pant_length_labels
# 799  Images/pant_length_labels/07c7f768076b25e93562...    pant_length_labels
#
#       label
# 0     nnynn
# 1     nynnn
# 2     ynnnn
# 3     nynnn
# 4     nynnn
# 5     ynnnn
# 6     nnynn
# 7     nmynn
# 8     nnnny
# 9     nynnn
# 10    ynnnn
# 11    nynnn
# 12    nnynn
# 13    ynnnn
# 14    nnnyn
# 15    ynnnn
# 16    nnnyn
# 17    nynnn
# 18    nnnyn
# 19    nnynn
# 20    nnnyn
# 21    nnnny
# 22    nnnny
# 23    nnynn
# 24    nnnny
# 25    nnynn
# 26    nnnyn
# 27    nnnny
# 28    ynnnn
# 29    ynnnn
# ..      ...
# 770  nynnnn
# 771  nnnynn
# 772  nnnnny
# 773  nnnynn
# 774  ynnnnn
# 775  nnnnyn
# 776  nnnnny
# 777  ynnnnn
# 778  nynnnn
# 779  ynnnnn
# 780  nnnnny
# 781  nnnynn
# 782  nnynnn
# 783  nnnynn
# 784  ynnnnn
# 785  nynnnn
# 786  nynnnn
# 787  nnynnn
# 788  nynnnn
# 789  nnnnyn
# 790  nnnnny
# 791  nynnnn
# 792  nnnynn
# 793  nynnnn
# 794  nnnnny
# 795  nnnnyn
# 796  nnynnn
# 797  nnynnn
# 798  ynnnnn
# 799  nynnnn
#
# [800 rows x 3 columns]
