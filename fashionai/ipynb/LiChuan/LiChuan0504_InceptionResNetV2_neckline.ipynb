# %% [markdown]
# * 将 trainset 分类保存至硬盘, 然后从硬盘读取, 避免 memory error 的问题
# * 将 validset 直接读取至内存, 这样可以节省很多运算时间

# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import itertools

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix


warnings.filterwarnings('ignore')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 分类存储数据

# %%
import os

def mkdir_if_not_exist(path):
    if not os.path.exists(os.path.join(*path)):
        os.makedirs(os.path.join(*path))

mkdir_if_not_exist(['./train_round2/train_valid'])

# %%
df_train = pd.read_csv('../../raw/train/Annotations/label.csv', header=None)
df_train.columns = ['image_id', 'class', 'label']
df_train.head()
# Out:
#                                             image_id                 class  \
# 0  Images/collar_design_labels/b23a3fe060d71bed77...  collar_design_labels
# 1  Images/collar_design_labels/0ef580b4deabcd9fa4...  collar_design_labels
# 2  Images/collar_design_labels/87ccc33937821a97ad...  collar_design_labels
# 3  Images/collar_design_labels/26caac7d1f1b36fb9d...  collar_design_labels
# 4  Images/collar_design_labels/396ab4e7cbc6798100...  collar_design_labels
#
#    label
# 0  ynnnn
# 1  ynnnn
# 2  nnynn
# 3  ynnnn
# 4  nynnn

# %%
classes = ['collar_design_labels', 'neckline_design_labels', 'skirt_length_labels',
          'sleeve_length_labels', 'neck_design_labels', 'coat_length_labels', 'lapel_design_labels',
          'pant_length_labels']

# %%
cur_class = classes[1]
df_load = df_train[(df_train['class'] == cur_class)].copy()
df_load.reset_index(inplace=True)
del df_load['index']

print('{0}: {1}'.format(cur_class, len(df_load)))
df_load.head()
# Out:
# neckline_design_labels: 16376
#                                             image_id                   class  \
# 0  Images/neckline_design_labels/ce4865335b52b79f...  neckline_design_labels
# 1  Images/neckline_design_labels/4f8654c099517d30...  neckline_design_labels
# 2  Images/neckline_design_labels/61052e51290d2960...  neckline_design_labels
# 3  Images/neckline_design_labels/e948921d89da972c...  neckline_design_labels
# 4  Images/neckline_design_labels/6b81ca0da1970654...  neckline_design_labels
#
#         label
# 0  nnnnnynnnn
# 1  nnnnnnnynn
# 2  nnnnnnnynn
# 3  ynnnnnnnnn
# 4  nnnnnnynnn

# %%
n_ration=0.9
valid_data=df_load[int(n_ration*len(df_load)):]
df_load=df_load[:int(n_ration*len(df_load))]

# %%
task = cur_class
image_path = []
for i in range(len(df_load)):
    image_path.append(('../../raw/train/' + df_load['image_id'][i], df_load['label'][i]))

# %%
image_path
# Out:
# [('../../raw/train/Images/neckline_design_labels/ce4865335b52b79ff9543dc4dace9345.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/4f8654c099517d303de0150e5fce66ad.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/61052e51290d2960151c538da7c3c973.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/e948921d89da972c1b11075519458f2e.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6b81ca0da1970654dd81ccde367c0ec5.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/e6ba3f7851a7c6170397c9b25c01f3bb.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/ac18b958cf253484945784a91da6d093.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9f30b07b215925eadb7962c1c5bf67af.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6b4ce4d54b1245f3fd2a8eb30cd0f303.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3ee9021cbc6b327eacb02e2d5f8d6559.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/d5a5f8476ca03df582d975e376063261.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/76481c6a8bb0a133d624948231792d0b.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f3226fad00ff8a9cceed5fbf2ba70a50.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8805b5d59b2bedcc14965ccee5d1ae40.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0c46332e98d68bced81c165bef4b50a8.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3090a5268a095aff3a4bc3be6782b88f.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/845772a9a1851d35e602ff950984715b.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6fc92842a7edda62e7658c98a421d701.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/a45e254914a14b56ef646b666c3c2ab8.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/04f9d525030e405353547504aef861ff.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/c7079983b4b582e67862d8625a051f17.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/fe9546f09d3b0ec83431223d27624976.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/5b6d69ba98713df9db38b7a497774415.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/4d79d6d04b3221efa6b952d7bff31b00.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/204b0ff8b431a525a065d4a07f92e7fb.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/1eebebc74afffcfad4c24c6a6ce836a4.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/2dcb6b4a97e995446f9f422ffc35fbac.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b228af55bac286ef77af538886100d1f.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ebe7bdf26dad2885babbf5b80023c937.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0788ff97d232811bbc838189351b8fce.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b18b4620d92617dab47b1026c5487bf7.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/00b90a795f355dff0f14d48822aadc06.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/54dbd8f4f5a72f6cd2918eb443a09c62.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/3d457aa0c353d6cecf018dc38713828c.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a9d26ab0004a89bc166247dfd00d018c.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/58bfbc61563f9d691652e124e4ce5fe5.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/9b91743847453b6eef7abd9e63d4b2ca.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9240180912a7236157a4942dfc406264.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0998d636321cb1156bc87d9446d14f1c.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/c25bc9a911ad4b93860101bcf24520fe.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/d40092a8b5a84096671b27f8bbf47a61.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/56d136b8e39965c50667582ff7f9e5f5.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/3bc426083aecb6d485e4f78d0e4caf59.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/83646e5f5d7eb07fd45fa7ec372822fd.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6af59a45f721ac5985af39665ff354c7.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f822364bc9da2be2889aa9df3a296303.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/9c6e5e1f1ea3edce0e919b2f4cbfbbe0.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/6bed1cc3a70df83c8ba5912c8d0ec7e9.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/23a6086a8b8ce3a4b0fd6b5cca19f9f7.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/5b1a11568a57623ac16fbb55c6e17875.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/2cf8e11b540afff5058e89ab91711684.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/af64882f37d7df8d5a505eeaa2357ead.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7923a80be4f9f77069c57b50f5a3c464.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/76e76d23160447531a9a98e03a26c439.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7f6894cf7402a3e2f03cfc1257086cb9.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/ddb73516f0ee39d057f19057a75ad769.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/239f42d55518ab978a11e5c7bd3f8765.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/76bfc32a74b2ace7cca8e8949c599f35.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/28d98bd96e992ab9fac95c2d085b224a.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/84b3e214709018079d2831082669a54d.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/cd542c0c7902a386baa723ec30b6ac9e.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ba05f76063ffe606982b0a42a4422025.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/39d56c9f50962fea10469e97aba31691.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b9ea8ebabbbaabc9f119324b8ec37faf.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/94440732cf75b48b83022c508a9d5414.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7d7faf220f2100cb85a42dddee9b6d9d.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/5a274534f146e40703666e4c51cde10d.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/dbd71137dc0d74259d6bd3b9aa2c8ab6.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/6e640115512ec3d64ec1fd3958aba155.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6c036259df93548446276afff2bd860b.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/41721e48f93bc442f619aef88de1e4fa.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/1354fb96b7d56ae7b8d1480a524789d8.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/973e0ae8131159b00d3d55c8d1c60817.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b9eee83c86922da3c1a3394efee88704.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e6f42168e5e98642131ee8c2d954bba1.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/f17b65cb54f296cf20cb0ee7683f6f6b.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/31d15d8f93da7ecf859fedb357c1f2ee.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8d603d92c475ebd6a603dfaba3812822.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/04ccbaa04706f7a3bb84232863dbd470.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/17982bb8d653cf8f57494e6de6cd926c.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/0dfcf7deee94c2d2cbffb3461f7c9068.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/09e68b18f005ccefe0f76ab38ef3eb50.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3d1274bf488361cee6917ca3f5ada266.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e71dd09d7d015adc6afad794595dc04b.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/62045f78de186cd21c68ce2d88642eb6.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/0edd275090b59a904c67e12d68af0096.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/07cbd3e538f888a96b772608ec9bce79.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/6245c3f536a22191967ec16ac0ee5717.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/59e7049848d0e73a725c1c78824ac61c.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8ce2c43cd721a9f1af64a01b3020b6d0.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ae79811cb3977d6c3061309aad0c6b6c.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/7a325804dc25249e2487f5996e2cfcaf.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/a74ea028fdf6e28b975d50872ce2d8ac.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/bcf42246c7e9cc1732d711c503341387.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/749e7dcffc74cf2a568b22216b9b8151.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/534734467f222dde1f243a92dc23efb8.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/014b860e24bf623e75c40f2032e643d6.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/920b51497503baed085216b89f687e6b.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/cbd55ae0b93bd7cdfdaa19f7e635c620.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0e7d44837486ba620d5bd5d4cea59019.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/40f6c2221ab604aa97f253789c8f3398.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/831ce0d9f852f01cbe312f77b7c128bb.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e8fd7176909a797c499454c7447e1be8.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/036ef56fe6064ba21c5ab3cdcbd2618e.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e26c82f6c227af5f2c1fe6e5cecb7c9f.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/360deb7d2d5d0c6812112bdcf7b83024.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/2ffd641306dbc59232cc41fa9b96da1a.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/2b7a25ad63190128125a2e6e0c4409e1.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/8db032d13958b3e5ab74d35ee57d5de1.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/71dbb24784dcf49afa9ce07adb2794c1.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/4b397adaaa3ccb88e61d6e9e4d859275.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/5872beb94e5dbb7b0dbc07c0bd451ea5.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/2dec3765178fa2ccc7d9c0b5051e5b4f.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/5b79efd8d1d95a278dc24720ff4d4f5b.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/fee790e70a52a597ac1a9f8e9da0f6b7.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e02493d8f6908badf09a192c2ab116dd.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/645308670537213119a9b1142f81683e.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9eeccc68832655b4441264d75d5acb3a.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/540c0a701f0e4bccfb56f4a14f65cc8d.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/282defa54ae7e7bdf6010fe4d2b3aec1.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/77d9d49e4c6c1a943814dad78ea53ad1.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ebcd2934ae5c67b401a2128a37a00fdf.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/2d9266b813d8e01b9a84ab7b8adb1149.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/071d7235b2d18552a9f19e2de85366e6.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/85d6f5acf3bfa4e27e417706f0292793.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/89cc62204ad9937c8d3e0216ea2dc3cd.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/cbc087c3fa5eaf021297d5244c162a61.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/286fe612114c43303bd456139c49a757.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8a7b992ebffb52bb98fd242250968850.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/a3079d1d1a87eca13b62e1ddc535ff29.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/69600a86a1bef30dd92d26e3867b4f79.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/f14d9a980d7bee6287efed34c66d2d05.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9f72614fbf7725367cc1f4dec9188845.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/50794b63fc07c38733e83f2b3f5a8cda.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/0ac372f85165b2cd67937a036bd92d65.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a15d9d7b63a3a6158712dea8a291c563.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/d293180bc63dc690085240ca886e32cc.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/706b3cadf46f28f2dc3c636bf01c08d0.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/433db8ff9030950eadf06327e16a866c.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/03dfb79b0fbc94d50bdc79be4cf5d903.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/ca5eca73164432e7d8d1962465833afc.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b469f93f207524d8d00383c3fda0af4b.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/eacefe29487072c0079f5297a415c9bc.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/edd932b3e1a9344fb70d7b015ab86350.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/41a4dde83c0fce4232f621dae113cc24.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f35aa9a8bd7ccf2110e35c41f77f3f3a.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/225c9189315d421622d47e75eabd7b4d.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9901fc44704cfa882adb6501910283c2.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/60fb303051cc7e476f5d7dd15a67c332.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/fa5a697191553a8922033262cbd4065d.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/df4302283c3b4523463a229a138c6ad9.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0b557288de972666fadf0b3e1838bd88.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/322319fc9a5d9310d8361f95b7b53919.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/e6a257a708b46782ef8f56503c723467.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3f353d2f6b4581d809cac51dfbe5e429.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ea3f3ab8f6d9aa2fb4b8cfb377dcee5b.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/f37c28f6a831d7d0a52a1e39f65b9a83.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8d2501aa4df048be4aa0008a701798de.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/1990e5b33408593d331f25f25716eaac.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/00e8b5291e32898d19354b2a06ae7bc8.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/2a2490660fd22f24063f01110d8e8da2.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/511f5d5d7011d6214e86d5489287e556.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/fc2a1ea585cf4fcb6d24c5d9ebfbc8e5.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/6d7d27731da62dad3735c5532cdebe38.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7de03f331a452ac9a62d06b9bef3f0b3.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/d4d478c667b8f09215d17a1967f695eb.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/dab982224aee209e13470ca88a70f59a.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/861f7221af1108660fac39cf39953625.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ec38a97fc59f1d7c3c12d8f666f2b9a4.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/231497ab54744b52f8206f1cc8582ce3.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/7e5b109d2984b1e5be624bc123173cb4.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/cec9713a97a114b53ac5bf3ea9c0c45c.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/206d62e1d787048b7215422554e498e9.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/be3c5805cf0f07e354ba8ed9aa6b4fc6.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f04e81af51d0e7ef6b34f829398220da.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/80eb0e6a79921c0357752793604c0261.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a6ab57155ba9100e79a95adaf348db80.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/8682c34b40ae0ad8c9ee5543b0d5eada.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/addaa5b00dc9816f54426cc98d36f33d.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/2d20779dca4f5d5acaf19b7b9f7bf213.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/eb5b7d0329d3d7db620bb4e8e4db8597.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/cff92635fe79ddda4fc96e9429ddd627.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/47df5b9d25f54629936e137069655e32.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f72568dba264f2ed3f0960e2f5ce9f1b.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3be591711024fbe863c2e4c2560ef004.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/2bcf5030658de6193fb8ea657a84412f.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/a05f3c3b27f2fa83fd885fe51814befd.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/28fcf790080e6f96d16d74d9046f184a.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/ea5d2502a897812c1fd6e7c49d55e00b.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/a1c7ba6a6b31cf6115313dae8e1ad9be.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8c4cbb605fb0aed6bd6ee37011d82c0d.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/49fe9c0adcfcd56c71509643410384f9.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7ab8b6b704b6ff70adf3431effd20485.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/1a5885f9a5a7cc4f9d576ff660d01f90.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/4a8e166b882b311bc4ec880969c72eea.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b0a220bf45068dcacc5750b9e0610b78.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/9879bfdc0ccd8d48eaf5e4891e30a341.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/587052e1d94f439ac14d2009887910d8.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/2471c68458ee2d630d6feac18a192ddd.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/c8b255766c9ef79ba650960e99b4e03d.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7190f5936db1ab373eb73a03b53c244b.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/4d4a475c00cad6a50cb0cbff435e27b1.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/a10de6cadcec958702bd846f97075af9.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/1e429028747f4ef8ee810e834ff514be.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/16204202802597618c6e6719502cc89a.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/9ac2054954fc02fe6200ddbdc773268a.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/82f4b0bc7cd8df541ebfb92dbc84af46.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/17aaab2da6601d8ca967d9117cbe3d5e.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a59ab7d96fafb1a17734145f183886de.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ff0b81527022a5097e8afd23f373e9d1.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/9effd571d38e7242dd44842af3144116.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b59d414755b28ed3f195532fc312e724.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/28436199278a094254d27f0eb0c2357f.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/45b487d4ba7ca2e789b236a4474ba5a9.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6362446f9930501b4859e332a451a875.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/d0b9ee6384755b14d128afedbfa7c091.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f1ba86ae1451d099c5880dea0b7e3020.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/7e63b26d3aaf196a0eedc42dae96f442.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/84023ca405ff688d3c623caaad6ef460.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/38a69eb0a50ada95f5932494474dfda8.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/93611882b018399d098d827337165912.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0870262eae358b6e5676303ab775faf6.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/fdefb4849deb603a500f8817760cba22.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/435a1a138c5f6123c06216a43d043b2d.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9a8b4ad18916445ce25e844dda19568f.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/48bd16e70cee67418d427913718bc472.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/d9c80557db4a4195751ca8b9d9dcce4f.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/5040b5be8df265d6e4816497a7f5711b.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6a5b7b739360144bc6f306dc12f9e5fc.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/70ec6d57702e990291a347de2bb062b1.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/159e6dc661298d8b447cab91302cbb72.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/38adc561e639a2dacf9c74f48c1529c1.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/2681e8a69e780079393795f351e70ccc.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/8b238ffa41a2b1d272b40806ad8225c9.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/8e5c8c714dc732cb9a77e3770abb17e5.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7a15c7da67b845f45e948b25d923bc31.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/0fac1a29eb0479c8a3e37aa16d2af84e.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/52bf7bc7676967ff048052e1a3a5162a.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/004a050c01232bc0aaf8a4bd06bcc750.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6228d0e83d3ed06c2aa9ada96262ee33.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/4550abd0ab68698022f441d7751b78e5.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/804e8dbd5eadaef58c09cb1f9e6ac224.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/d8e05869befb536b1b784113f0a9d2f6.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/2c0eca6c54239194fb0a438f68f005d5.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/cf0a742c26491fdf0737934881101ebd.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/2166f8bda77f6faa9f07ff8c04a2fac3.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/4c2640e9e9bb70dc67e62b0cb6c00031.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/e25515c727898059bc09cc8d6eec820f.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/178172ff20fea5d3d82becc340e9f5e9.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/81ece73e4bb934fac040ed16d1cab03a.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/9ac0d8e9a73b06e9faadb406bcc55d9b.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/6c609d048f5ef74fd71cbe689b540b40.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f13c9ec92c30e0a2e7c934b6c2fe9421.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/0736a4c89bda9c4a1d87e00751e49611.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/1ec5de0eea48f03cc866bfca98fcf49f.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3e7160216c099c60806e93c2bce5ee31.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0332b06ae3c627de18ec08fe3f1a9a05.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/71a010c5808b8f64cf46e03d347486e5.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/aeb9e1e415a66074f0b899ddb768be95.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/d5246d65529684d71cd41852cea77fe2.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/b4e964e6460d43624cc4447978638acf.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/2c3d6e6cc2cb426515baccee48e659cf.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/3a1cc7d08c2904966961afef0ebc8769.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/e088b02e9e083e3fd8a31e0e46a17f2f.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/17113c17e400574b428d6a749475f9a9.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/1a051046b245389f560d70793748b617.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/ffad2f1c3195a4b4e254a5a052c72d8c.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f9073f3d5c1aec6b5fb15c93fb301f33.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/4beb47665585a09dc33a12d0d82a5c47.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/ab3101810d74682c44e6d65936f93faa.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/114e4921b68b8036db56fbdeb24234cc.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/8415ec91662a130ff53ab05afc59c5e2.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6529407ea6a7d3f00ffd7ef42000cad0.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/b3108890b1d8de1fab39f32eb3eb2983.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/2c370fdca7196efc09ee52022cb0e7f0.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/f21ed8b0bcaee8353ebf4509987b83f5.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/07b6031f119e22ad84a6017d5fa9e4ac.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/9c14eee49d47718f705a4c6bbbfe98f9.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/fc9c4aadd087cb1e67f7ebde6e665c85.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7a1351561f270633f3407633355a4c53.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/584e9582ab9f408cfbc36c29ef7ae002.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/f0833d2679a4fb401003c301f9ba1abb.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/46f8fd931b2d36592d3be5e66727f990.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/c0635757997b41182f29de278ff4e3cc.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/dbd049904cdb34e6c0abf4c5856b4897.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/379366f9668d072b920734a2f23af8fc.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/77df95d6cfc719996e1d62504eea5b6e.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/9ec82aa946ea5df40ffd35c72ade22a7.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7b7c02f5077dc3bc5c1f1548d6db0d0e.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/b96a16154d068d80a2f0c555cad5faee.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/2edab9e4bcd2813719f48864ff5c7f05.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/75afe60bc8fa4f18e071e8d650148333.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/2bdcce09fa45e73657d2946958bb5a19.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8c6615ce75641235a5a4774d32be28d4.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/46f4047dc8cb72ccaace667cc2bb21f3.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/bd3eeac163c9434846ef67d7bb1684d0.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/78b89fa83b64e89894dc9ccdf8b6c8b1.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9e1120d4cd7876ca6871ae4ee3aeb850.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a3f9de3007c9d49c7571906dfadf3f76.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7bed64d208eb965aded79c3532f36654.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e4654f0c056f7121a9849e7d8ff905c8.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b9ad2478f01128bfc7d6c70011fd8426.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/bf9b0b0c380679e09613c8e46793973b.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/d433443aea2701424d5e0c759fb44599.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/5406a9b19c2c91aa9ea34d16a25bf7b4.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0601a922928e8e36cf3be4873a317ddc.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/02773046f57f4b718a44dc7cc962b37c.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/5da8b7b32e2f77fc3689c22b0e24cce1.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/fb94883080601cd0a8d8c2205b818c1b.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a1a618c4de9e4391595b491efb98f7b4.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ed00a6732643338c4b7f7bf6441155ef.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e3661358cedf668c90d296c9727fc16b.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/ea055dac89325b8139f1e73ccbe62ac8.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a6cec58789da1ee5f42a2f245001f2ad.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/d7fe932e61507e844bc8e1ea47bf6d2c.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6f5e11aace1a0c1f6e2a156fcf5384ef.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8a79e5b9961e5edce622c316a85c1ab1.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/47c058375be283cbe225f0f8b654067f.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/eae096e4dd193df94c91bdd1dec1c03d.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/990e1c34b4d64de56976ab116e665c6a.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/144610876f9fdeef8a3f3ff7bc3fd742.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/73ffbaa501ec1a6d61f392383f0b0e43.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/5cd7204a454960a3a53e253ae1d3b6a2.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/1eed5e537f8ef1c6d759ac30184bea9b.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/eb293a6def2a0d9a4b94253f70ffc59e.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/0196658f5585c9ece35e372366c6d503.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/5a71761e1f96896e80dd1cf9505f4ccb.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/aaa26ae29e1880b20adc7264fc2c3278.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/431bba4e351c2eb401c6e43c84977eec.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/e4cfb3e9f272b96493d8cf430d889bd2.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/327a25d9e94ce0fe49bab5b63a5ec959.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/50c084c812aaf7cbfa668a601bbda798.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/c22a9affe20256375abe89490832bafa.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/41f7efebb974752b89fb290232d39c80.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a369e1bab955c2eea64d5cd7ec811967.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/3856214ab75366828ca742ff81ac07ba.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/246290b2959def518542637247229e6a.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/28735fd694721927d2d40bb98161f39d.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b62e5eeea1ec883a1c2ba0db0d065c9c.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f419593f34d0832cf6953539215245a5.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f911854c9cfe9cf1ba15ac12173947bc.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/4f2239d9ab2657140ff210d138ed6158.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/1638acb9e92003f3eade41bb0c88ca65.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/c112450bd27f3339f5bb9c40d7c4c750.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/46ef1bdd515eb84a96f812545b7e7f29.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/7f8415f29dfaa86de922a35f99ccec0a.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/cecdb036925f1ae826e6b63aff53d896.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/d5e0c245cf6dc57c975b0b978125c793.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/63a66564ebd4fc8898c4b7a9a888daa3.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/2742e9bd4581ba1e96e23ffee54f6ee8.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/f6bb67652faf5f8162560e851b4e7652.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/862ad913f2e144394947c5ef1580fb84.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/4aed92e41ac5446fa75974e3bccdd4d5.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9cf8bef78783ffe8b72046b826f69377.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/67163114b153d37099c44e999594ee6c.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/0677834aa5c9d3f9b8a57b439a649dd1.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3e5509eda6d75b9c5d6380f0eda4c0d5.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/66003805d585652f18becb637441b213.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/a79713ace0bac3b76cdfb99de2b8e0c0.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f38baca14ed50cdb1034b21d70cc04b3.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/7e52072192e972ab0862559d8a088d75.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/ff76837d11fbad53684f7b96c1289edf.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/d1eeeadcbdeabb6fec6cfeb411f669a5.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/d761d656dc93ba8126f69c638dc6e006.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/43d49421ad028f0475fe8c19bb3a327e.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/41adcd683184014e0dbd5d59c1c26073.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e6f497e243069df590dc11c389c740dd.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7491438ed01f029dcde8793dda4eebd3.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/908fbedd55074c31db247e97bf41b465.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/220e9c0a0a1187023029546a4fc5fb7a.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3af4847d53f53978d98b29d956c54210.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/0ac06e505e7aad1b3879cd72a4335548.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/90d8c444be8675c3e265891ecd4a43e5.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9e81a77bb2b6894ed93a05de45f8b650.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/83f61557fd846d72deeec8ab403c6a25.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ce8c702eea7906804a78b94f925c4b51.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f1d0f995e378cff20e1b917a2e3397e0.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/22b73703dd49b48bbfdfdd5f982a4f2a.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9381146bbb95dec7de032e7a89f7d677.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f19a1fdc645cd3e2d73f0fb5862d9755.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/649b50a413bf09e5614d7c475bff49c0.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/aa80d5762721ef30fb9143f90c428407.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a71054a6ae31a587b877300a3587852f.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/638bcd99911843e526e26f766927d37e.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/98ab271749e5c5b7c43b0d85c3caad50.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/7eee15e96cd854bad88daf3a18f6f90b.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/2fccce61d02e9007f77599f8cb5dcac6.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/16fa103bfc0d8e088f9db039271a62b9.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/4876853ad70ca139c62497bb18eb2780.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8609d1bf921e5d848c347ad95fbd57aa.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/5e90bf8281fbab2a5dfb8e95ca49a378.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/f2bd202ca664b050ee18766dc0d87f57.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/a36ac67bb8a99360d7962e63db4db25f.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/19fb9865d50c8aef30c50c0122310334.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/788e5823828da3be86d2df0dc8af5d54.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/95a25e88ff41be598b812d002878c74e.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/f0c6d3b5efc86e46ba38c21063b2e420.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/47d3d72af8e958bee2310c5cd78e73a7.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/17f85ccc7bd28c31b6c06f79c51d9593.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/2e024999c0c2b11f9d7ab4243ee0341c.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/199afd156227909b6f7ecb27a684865b.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/e54ed7fc54afdf93c2424a17255012ad.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7a6d762d6de3c80b6b8df3afa5c18d9c.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/282d0ab66816c1b9e3d0e06f34cd66cf.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e57ebd9bd426de7a62a113204813133c.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/3257bea20d2b71158f178b77eb36f072.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6c0baa25f855592f7a856ac46b7cce8e.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8ca36c442ba464bebac38daf6feafa2f.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/497f5b6f2b857832277ad6e7ac23f8ee.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/e2c16ceec69918689af70a9e1fad308b.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b401a2786444371de0d797a811e9f5a4.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/1d59b43a3599c1798557e3ffea2ea43e.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/904312e095f8d4ea6b8a3320f2cd3944.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/b72b257f60272e532ec60b239d4450b7.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/af26f88ae56d8bb89cfe6d2ee9b6036f.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/303e481657c774b8b2247b20365ed86f.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/f3040fc967d9619f9247742c44d84337.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/ff916649e83d2a1d6046f5b04b4b5d07.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/ab27f29ffb3eb52f184852ffd673af98.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/531b06117f788866303cb161a6de1ffb.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/1f64a75c47ba98795e78f2a9a9c25f44.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/4ffdbc026c8ac3b98b3f69d0751a2d3c.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/558687b90a4ac7cbed23c6b2b354cf90.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f72d307370cc68ddcdb47182cb719bdc.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/1da780f310aec6e4d80701e8be470652.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8ce82c5a38807fc48d88010e8e6ca3b9.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/36f6223f81d80dadf2706262eef8b9fb.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/86e5d9191e1cd596e484f8734ee0fb5d.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/5f6e99af6b7e548cd1d1fa801a03b6d9.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/826ce1d6d00aa4e3f69724bdf3e1e875.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/d0e38a59a9c47fe5dbde3dd6cd55996e.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/11f6f50b500de5f0f82f085a04ec3b15.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/ec0e023449c643f3fafdbe1430d24d20.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/00315a7b65a8d00c25acfa8f3bd3a24e.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f5e918a8e3a5c11911602b0380bbfed5.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/c93c15b574c8fd4e1a3ebceb56af0201.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/1e39e9f42e0a21eaa25a7f12d099ee23.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e2099c41db1929d479851992ac9ba1ed.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a48f7b0194c0c317d734826f29b7cab4.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/c94c06b8ca8753e93e3b5103aaa81242.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/8da544b950fa6d02b8ddf8f879f6980a.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ca0c4123ee4209d74b71562c6e1c9b56.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/ff875bf73d9107f2dccc7e1b06dc0225.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/eba3a2f26fd3ffc6aa6a50b63dfea02f.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/abb3e216d466ab6edbc5118fee2c7baa.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/43f328e5de95f7e1498f335e6e6cde9f.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e4f005ffafc346ce50ad549e93f1f304.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/80dc7c64efa4816a5348bc29c0eb5a33.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/675dbd58c7b22e388b20f4a160ef9b37.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0763228cab63db3e64ce307b6a5c05f1.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/51dac3c6b7a08302798ffefe80ddfac0.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/2f9d23de8c8d277bc30233b4ed153205.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/79e5e908b02f6ab446ec740e5e4bfcb3.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/0e5ad17740044326d7f6d669a38656dc.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/285c72ca39949787086267852ed5e1e9.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/1641a96bc0687cbb106db2399c92099d.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/805f5d842f8a721be832c26272ad808c.jpg',
#   'nnnnnnnnny'),
# ...
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/4a2ee58f4622a83d85b197d157c8cb87.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/555167e1911526d22f63e021a35260b9.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/1a4be8bf2775c2146d8369221677bef1.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ebbb235d98d8fac66f0bf3500d6be310.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e45b12742c132ec3d3a64973fa8e1878.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3925292f824318c165eba33e366bd818.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8d4c4299b89262b579aca0bfc3ba700f.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/197238a1e3303878e6ab0d26753107b3.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/72afb81d08de6684bd978b3179c7e212.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/8bf2fb29d4f81fbc4d6b21179fba9fdf.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/e4110bbfedc14809b0a1069244f8d312.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a6fe79478e0bf887b8824d2e6ceea30e.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/2337d3fad3311d1a05692a054ca12f34.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/60cf07a35c5bb7eff96437c16e3da80f.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/aa6bc6219fc6c81cb28d19f1a04eae49.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a062e97547432e871b918802c8f9614d.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/52b257bfde84543128f25b62ee293763.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/f7f5234771d37ef761d29e2d784b301f.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ab2782d097bc55e335f6c80647d7572c.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/525e989658f69ef43ae250932d2861b8.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/5998dec4647754e62682e6ea49779ec3.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a770709e263f53d061c77ea82da51d6b.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8e4fba4322bf095e6439aebef4e8ac55.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/aabd5dfeae0163811ab894ed7dd122d2.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/251e323bd1dcf0c047b54b6f7bea6e59.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/cf8205c70ae5099803ecefc6b7db4643.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/05fad1f9b36ce278d17f875ecde9d1c2.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/08441e80bc1e32ce3c77267c213dcbba.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/da8bbf6c0d59970ec337fddf71a81981.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/6d8ec5f8b199933db22778a73647a4a4.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/58c8cce2aeb71581d517cfa9453f21cf.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/8cdc0b383f7196db191e99816406c495.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/c89311765f44d7559877d073f201b572.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/abc3bffcdc9a81ab4850bd945416df21.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/db591101211dee57b4806f5fdd7deff6.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/6ef1620382260a0fc213f1147b287c43.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/80ee8ed0d1d274d795079d11af4e3b20.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/8008a3be02d90c3ca831288d66828628.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/5bd64c1b9387c09d8308092db04c0ee7.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/f48a2309a01316bd638e77b15cf2f08f.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/e6623d5894813dba033b8ea85b57f68e.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/c772dea2f09110cac819789965fdcbf9.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ac04959ef55e527f96280a62665753a3.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/06fa77121e6049ed06c2da731a6a719d.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/2b56d4b4299deb9f458e4830f51b52e1.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7ba51c4e6924fe2e7d21a0c3357815a3.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/1f7c071f0ef9c69e924f9e0ee918942c.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/9ad8361e9e2e30d92f3b7e96d8768dd1.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3e76eccc1d6ca1c926092c3c98b4107a.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/bc827263450df55d8f30dfbb5723f76f.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/49fdbb39e5e678748182b4da0189eeba.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/2107380a8d29d935537444121843d397.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/e09f46ce6f3dfd79b0fc9398788d52a1.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3a4415924f4853dd69163a6370328d6c.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/169b4cc148c5a288bad6181a773dc9d9.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a57e0b774456ca4e2d07c2c64ab319f6.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/33370bc9970d2be77fdfcf2dd91c65e0.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/45b0599672da2c53a0ab5f119050a641.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/b09c1f30024187eab630d5b3630c16bd.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/082bf3938af1e263cc8eefdd7b305839.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/fad67ea4127ae92d88632868c17a8000.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/03d35905ce59761240285d8a73a7a28a.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/094f91796f75424f0a7bb4d495e089e2.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/ba51ce40facfc2ba9aae4b3d98ce842a.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/c20f3b682c85de5b15292fcfaf2dad97.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/35b708a9917a2f6fbce69cd314942a18.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a0f7cb9843144d46bb7cef141fa4d19c.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/768bda0864bc7ecbdacca6f7969c56fb.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ee2db57425bcdc604f82d1887c496614.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/dcfe73e3f1f0e1778205412a805c8d23.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/30e4e9a55074d9fbc4a2afa0672de914.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/46fd911efb44cad2ff108843cd2f7cf6.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/8b0ec91b2f0fb86347225a52bd9e0228.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/77121646d6165654fe9411148c390deb.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/6baa03bf6fd95c48a8d09e5899ec4aa4.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/4b59e020ff2380fba709a782a6296e53.jpg',
#   'nnynnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/06f0ba0b45410cf5e3e47fc134a004e4.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/4ab8639d1ff7382137b698cf76166f22.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/65b36e3674bf282421b1c1aef47bf282.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/742d699c53659d807fca512a19870338.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b5498bc23e5d7c4135f10582556fa58e.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b1f3da08df38ee67e14dd2bbdc415a32.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/214922813ff8d58e0acf626523e6588d.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/02b2e5e3272fb4f249bd0d10f3532b29.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/ab82706161608bf2659029eee5ba28a7.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/ba91cf77c56fefb6f2ef5a198547dcb1.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/4b2b3a680dfbcf47f407561697c444ea.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/920092b1c0def95e077d26ddef6ca667.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b70966520bf189ddb83423a14131ed50.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/a01043b05edc824fb4099218ac2895a6.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b0e6f28a2e28ffe426f27e0a1794e944.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3844551c44ef706f0321622af48db225.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7c02f099255b37c39872b99d88601cca.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7a133a8ef993e109db7f31bca162a133.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/33db4795d108e8bbae1e77225605f428.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/5fab5e64a0a88b9702fc794f8ab08570.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b21447c4aaf4a7f3dc330f1fb1d5fce8.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/73f976c274cd37525b866864aacccf8b.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/131960316998fd4dc216f5c7a11df5ed.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/0bc19265d6f48a443d2df4fce6e87b5f.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/22939636b79d32a9e369e11c5551795d.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/59d0b8e4879a68928f2957df660f8ad7.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/87b005800ac0fcc7e9a9987aa7682cb7.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/a0937b2d2e8be1806b39504fc75945a5.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a4b25bd5af730e77c4a3bf5badc41afa.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/14eadabae42cca9ca4ef118ebaa7a985.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/923bd77c2a3ece78f1f77de254bb312f.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/df81dc019757ccc47b1dfdd9fe91d2ec.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/48193add326eb55e0c97aceb7ddaae0b.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/7298a1c11ed1592c679e46fcf73790a9.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b1e3ad0e8a91076c911070996c3bc2f4.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/01b2498a93b5a5353f784205e6bae9e5.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/76de1ccfe78c986eac8bceb0fc8cdc1a.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/b952e6ea66993c4a5686601a740b48a9.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/6814044f0208f3d9bec9e0ac15281bb1.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/0e610dd26021750db175b7279b09866a.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/b06fb7082ad37ad75c0789f4eaf9a527.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/86c9fd949805fa859aa8465acd3b86f4.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/581eb4a89b7ad56cde637c14d1360411.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/51c8ecba180a32b15d69464d010f7d3c.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/24e025f2df492060c2dca45e5e18a667.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/dd7bd1ba531334eec1f835150b008717.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/a1dbccc985b78531cce2e4b3e1e54596.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/635ec6e2b10d98d4d268c005963fe584.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/bd6aaf9cb21285f00c7ea19c776b4e5f.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/558af7031b4c38f47de3075a41e72bc2.jpg',
#   'nnnnnnnnny'),
#  ('../../raw/train/Images/neckline_design_labels/a38aa0a0ddc2a4ac04f8aeaf53266aaf.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/8e3af8e2f8bb5f8160e15220c0045720.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/52b5c8aca497f757cf6a932d698de66b.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/5524f4b05c9bba61bcd70e8f9528e4c2.jpg',
#   'nynnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/5fc3d3463367b50c5eb136d2607e5a88.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/62d93f7e652b0cb1e26350490cb4e8a1.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/3d5e80a830bfe5c824f53068433b3333.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/752dcfef208cd90c9972524278c246bd.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/3e6ec8e2c908f299f01ffaebf3878334.jpg',
#   'ynnnnnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/90133d000df0494eced9e7db2bc479fb.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/a0198ac86ce953813d684329140d378f.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/70fbc881e7ac89f7bc71f6e10eb6877e.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/7bbdb1b1c3b41d648249cd58c117c6f4.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/e93aa6b2c581fb5dc2c80aa1c3692fdc.jpg',
#   'mnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/a903bbdb1092db03219ff3455c71b561.jpg',
#   'nnnnnnnnyn'),
#  ('../../raw/train/Images/neckline_design_labels/f747240367d8efcb8631e68a7d148102.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/2c91e549336741acd71ec7458d08f833.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/86db989264131c0999d5ac9ad4fe7115.jpg',
#   'nnnnnnynnn'),
#  ('../../raw/train/Images/neckline_design_labels/1b17a11d8005397afae8d01d8ff0b282.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/af23c22047c25549a448d53a0ebf4b38.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/33328606b7a9ea0eb7bd4512da526bd5.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/35db7362857eb0381b806e502e783741.jpg',
#   'nnnnynnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/4dd3c5ca99803e995db09508f6f7adc3.jpg',
#   'nnnynnnnnn'),
#  ('../../raw/train/Images/neckline_design_labels/4f89e3d7633c7757e103107b9f5d67e1.jpg',
#   'nnnnnnnynn'),
#  ('../../raw/train/Images/neckline_design_labels/2917a6fa0bd848e22e88885813243699.jpg',
#   'nnnnnynnnn'),
#  ('../../raw/train/Images/neckline_design_labels/5c5031f3a9e6567a53265003c3c15194.jpg',
#   'nnnnnnynnn'),
#  ...]

# %%
n_class = len(df_load['label'][0])
width = 299 # 定义图片大小

# %%
mkdir_if_not_exist(['./train_round2/train_valid', task])
mkdir_if_not_exist(['./train_round2/train_valid', task, 'train'])
# mkdir_if_not_exist(['./train_round2/train_valid', task, 'val'])
m = len(list(image_path[0][1]))
for mm in range(m):
    mkdir_if_not_exist(['./train_round2/train_valid', task, 'train', str(mm)])
#     mkdir_if_not_exist(['./train_round2/train_valid', task, 'val', str(mm)])

# %% [markdown]
# ## 划分训练集和验证集

# %%
import random, shutil

n = len(image_path)
random.seed(1024)
random.shuffle(image_path)
train_count = 0
for path, label in image_path:
    label_index = list(label).index('y')
    if train_count < n * 0.9:
        shutil.copy(path,
                    os.path.join('./train_round2/train_valid', task, 'train', str(label_index)))
    else:
        shutil.copy(path,
                    os.path.join('./train_round2/train_valid', task, 'val', str(label_index)))
    train_count += 1

# %%
valid_data.reset_index(inplace=True)
del valid_data['index']

# %%
n_valid=len(valid_data)
X_valid = np.zeros((n_valid, width, width, 3), dtype=np.uint8)
y_valid = np.zeros((n_valid, n_class), dtype=np.uint8)
for i in tqdm(range(n_valid)):
    tmp_label = valid_data['label'][i]
    if len(tmp_label) > n_class:
        print(df_load['image_id'][i])
    X_valid[i] = cv2.resize(cv2.imread('../../raw/train/{0}'.format(valid_data['image_id'][i])), (width, width))
    y_valid[i][tmp_label.find('y')] = 1

# %% [markdown]
# ## 提取特征

# %%
from keras.layers import *
from keras.models import *
from keras.callbacks import *
from keras.optimizers import *
from keras.applications import *
from keras.regularizers import *
from keras.applications.inception_v3 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.optimizers import RMSprop
import keras
import gc
# Out:
# Using TensorFlow backend.

# %%
cnn_model = InceptionResNetV2(include_top=False, input_shape=(width, width, 3), weights='imagenet')

# %%
inputs = Input((width, width, 3))

x = inputs
x = Lambda(preprocess_input, name='preprocessing')(x)
x = cnn_model(x)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(n_class, activation='softmax', name='softmax')(x)

model = Model(inputs, x)

# %%
prefix_cls = cur_class.split('_')[0]
prefix_cls
# Out:
# 'neckline'

# %% [markdown]
# ## 划分训练/测试集

# %%
# Compile the model
adam = Adam(lr=0.001) 

model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Set a learning rate annealer
# learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc',
#                                             patience=3,
#                                             verbose=1,
#                                             factor=0.1,
#                                             min_lr=0.00001)
epochs = 16
batch_size = 32

# %% [markdown]
# ## 数据增强

# %%
datagen = ImageDataGenerator(
        featurewise_center = False, # set input mean to 0 over the dataset
        samplewise_center = False, # set each sample mean to 0
        featurewise_std_normalization = False, # divide inputs by std of the dataset
        samplewise_std_normalization = False, # divide each input by its std
        zca_whitening = False, # apply ZCA whitening
        rotation_range = 10, # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.07, # randomly zoom image
        width_shift_range = 0.08, # randomly shift images horizontally (fraction of total width)
        height_shift_range = 0.08, # randomly shift images vertivally (fraction of total heigth)
        horizontal_flip = True, # randomly flip images
        vertical_flip = False,
        shear_range = 0.05,
        fill_mode = 'constant',
        cval = 0)

# %%
train_generator = datagen.flow_from_directory(
        './train_round2/train_valid/{0}/train'.format(task),
        target_size=(width, width),
        batch_size=32,
        class_mode='categorical')

# validation_generator = test_datagen.flow_from_directory(
#         './train_round2/train_valid/{0}/val'.format(task),
#         target_size=(width, width),
#         batch_size=32,
#         class_mode='categorical')
# Out:
# Found 7989 images belonging to 5 classes.
# Found 887 images belonging to 5 classes.

# %% [markdown]
# - 少量旋转
# - 少量偏移
# - 水平翻转
# - 垂直翻转

# %%
int(len(image_path)*0.9)
# Out:
# 7988

# %%
prefix_cls = cur_class.split('_')[0]

checkpointer = ModelCheckpoint(filepath='./models/{0}.best0503_InceptionResNetV2.h5'.format(prefix_cls), verbose=1, 
                               save_best_only=True, mode='val_acc')

try:
    # Fit the model
    history = model.fit_generator(train_generator,
                                  epochs=epochs,
#                                   validation_data = validation_generator,
                                  validation_data = (X_valid, y_valid),
                                  verbose=2, 
                                  steps_per_epoch= int(len(image_path)) // batch_size,
#                                   validation_steps= int(len(image_path)*0.9) // batch_size,
                                  callbacks=[EarlyStopping(patience=5), checkpointer])
except KeyboardInterrupt:
    print('KeyboardInterrupt')
# Out:
# Epoch 1/16

# %%
cnn_model = InceptionResNetV2(include_top=False, input_shape=(width, width, 3), weights='imagenet')

# %%
inputs = Input((width, width, 3))

x = inputs
x = Lambda(preprocess_input, name='preprocessing')(x)
x = cnn_model(x)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(n_class, activation='softmax', name='softmax')(x)

model = Model(inputs, x)

# %%
# Compile the model
adam = Adam(lr=0.0001) 

model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Set a learning rate annealer
# learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc',
#                                             patience=3,
#                                             verbose=1,
#                                             factor=0.1,
#                                             min_lr=0.00001)
epochs = 16
batch_size = 32

# %%
model.load_weights('./models/{}.best0503_InceptionResNetV2.h5'.format(prefix_cls)) #加载以前训练好的模型，继续测试

# %%
prefix_cls = cur_class.split('_')[0]

checkpointer = ModelCheckpoint(filepath='./models/{0}.best0503_InceptionResNetV2.h5'.format(prefix_cls), verbose=1, 
                               save_best_only=True, mode='val_acc')

try:
    # Fit the model
    history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size, shuffle = True),
                                  epochs=epochs,
                                  #validation_data = vaildgen.flow(X_valid, y_valid,batch_size=batch_size, shuffle = False),
                                  validation_data = (X_valid, y_valid),
                                  verbose=2, 
                                  steps_per_epoch=X_train.shape[0] // batch_size,
                                  validation_steps= X_train.shape[0] // batch_size,
                                  callbacks=[EarlyStopping(patience=5), checkpointer])
except KeyboardInterrupt:
    print('KeyboardInterrupt')
# Out:
# Epoch 1/16
# Epoch 00001: val_loss improved from inf to 0.31842, saving model to ./models/pant.best0419_InceptionResNetV2.h5
#  - 211s - loss: 0.2456 - acc: 0.9073 - val_loss: 0.3184 - val_acc: 0.8839
# Epoch 2/16
# Epoch 00002: val_loss did not improve
#  - 168s - loss: 0.1771 - acc: 0.9360 - val_loss: 0.3609 - val_acc: 0.8761
# Epoch 3/16
# Epoch 00003: val_loss did not improve
#  - 169s - loss: 0.1360 - acc: 0.9523 - val_loss: 0.3295 - val_acc: 0.8839
# Epoch 4/16
# KeyboardInterrupt

# %% [markdown]
# ## 加载模型

# %%
df_test = pd.read_csv('./week-rank/Tests/question.csv', header=None)
df_test.columns = ['image_id', 'class', 'x']
del df_test['x']
df_test.head()
# Out:
#                                             image_id                 class
# 0  Images/collar_design_labels/faad3490a16c7f3d4f...  collar_design_labels
# 1  Images/collar_design_labels/0b2b4254f35ce3a41a...  collar_design_labels
# 2  Images/collar_design_labels/7f2be608e06f804dd5...  collar_design_labels
# 3  Images/collar_design_labels/4b09d4dca80caac42e...  collar_design_labels
# 4  Images/collar_design_labels/de91f00a05e84d7239...  collar_design_labels

# %%
df_load = df_test[(df_test['class'] == cur_class)].copy()
df_load.reset_index(inplace=True)
del df_load['index']

print('{0}: {1}'.format(cur_class, len(df_load)))
df_load.head()
# Out:
# pant_length_labels: 1434
#                                             image_id               class
# 0  Images/pant_length_labels/e78538758763e84e9700...  pant_length_labels
# 1  Images/pant_length_labels/1e680886dd3d65882745...  pant_length_labels
# 2  Images/pant_length_labels/7e25106e7a0f5ac5d26a...  pant_length_labels
# 3  Images/pant_length_labels/53fa07f57908d258f4ba...  pant_length_labels
# 4  Images/pant_length_labels/737319237b262a9515a5...  pant_length_labels

# %%
'./week-rank/{0}'.format(df_load['image_id'][0])
# Out:
# './z_rank/Images/pant_length_labels/e78538758763e84e97009dda11754b47.jpg'

# %%
n = len(df_load)
X_test = np.zeros((n, width, width, 3), dtype=np.uint8)

for i in tqdm(range(n)):
    X_test[i] = cv2.resize(cv2.imread('./z_rank/{0}'.format(df_load['image_id'][i])), (width, width))
# Out:
# 100%|██████████| 1434/1434 [00:08<00:00, 173.38it/s]

# %%
model.load_weights('./models/{}.best0502_InceptionResNetV2.h5'.format(prefix_cls))

# %%
test_np = model.predict(X_test, batch_size=256)

# %%
test_np.shape
# Out:
# (1434, 6)

# %%
result = []

for i, row in df_load.iterrows():
    tmp_list = test_np[i]
    tmp_result = ''
    for tmp_ret in tmp_list:
        tmp_result += '{:.4f};'.format(tmp_ret)
        
    result.append(tmp_result[:-1])

df_load['result'] = result
df_load.head()
# Out:
#                                             image_id               class  \
# 0  Images/pant_length_labels/e78538758763e84e9700...  pant_length_labels
# 1  Images/pant_length_labels/1e680886dd3d65882745...  pant_length_labels
# 2  Images/pant_length_labels/7e25106e7a0f5ac5d26a...  pant_length_labels
# 3  Images/pant_length_labels/53fa07f57908d258f4ba...  pant_length_labels
# 4  Images/pant_length_labels/737319237b262a9515a5...  pant_length_labels
#
#                                       result
# 0  0.0000;0.0000;0.0000;0.0038;0.1913;0.8049
# 1  0.0057;0.0094;0.7786;0.1921;0.0107;0.0035
# 2  0.8354;0.1444;0.0087;0.0020;0.0045;0.0051
# 3  0.0003;0.0000;0.0004;0.9891;0.0099;0.0003
# 4  0.0000;0.0000;0.0000;0.0004;0.0578;0.9417

# %%
df_load.to_csv('./result/{}_0502_InceptionResNetV2.csv'.format('pant'), header=None, index=False)
