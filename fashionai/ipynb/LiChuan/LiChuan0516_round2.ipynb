# %% [markdown]
# - 18.5.21
#     * 做 4 种图片预处理, 原图, 水平翻转, 水平翻转+直方均衡, 原图+对比拉伸
#
#
# * 在模型一的基础上, 继续训练 round2

# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import itertools

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix


warnings.filterwarnings('ignore')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 导入数据

# %%
import os

def mkdir_if_not_exist(path):
    if not os.path.exists(os.path.join(*path)):
        os.makedirs(os.path.join(*path))

mkdir_if_not_exist(['./data/round2/preprocessing'])

# %%
df_train = pd.read_csv('./data/train/Annotations/label.csv')
df_train.columns = ['image_id', 'class', 'label']
df_train.head()
# Out:
#                                             image_id                 class  \
# 0  Images/collar_design_labels/0ef580b4deabcd9fa4...  collar_design_labels
# 1  Images/collar_design_labels/87ccc33937821a97ad...  collar_design_labels
# 2  Images/collar_design_labels/26caac7d1f1b36fb9d...  collar_design_labels
# 3  Images/collar_design_labels/396ab4e7cbc6798100...  collar_design_labels
# 4  Images/collar_design_labels/fc4a679c2bf209de13...  collar_design_labels
#
#    label
# 0  ynnnn
# 1  nnynn
# 2  ynnnn
# 3  nynnn
# 4  ynnnn

# %%
classes = ['collar_design_labels', 'neckline_design_labels', 'skirt_length_labels',
          'sleeve_length_labels', 'neck_design_labels', 'coat_length_labels', 'lapel_design_labels',
          'pant_length_labels']

# %% [markdown]
# ## 加载数据

# %%
cur_class = classes[1]
df_load = df_train[(df_train['class'] == cur_class)].copy()
df_load.reset_index(inplace=True)
del df_load['index']

print('{0}: {1}'.format(cur_class, len(df_load)))
df_load.head()
# Out:
# neckline_design_labels: 16376
#                                             image_id                   class  \
# 0  Images/neckline_design_labels/ce4865335b52b79f...  neckline_design_labels
# 1  Images/neckline_design_labels/4f8654c099517d30...  neckline_design_labels
# 2  Images/neckline_design_labels/61052e51290d2960...  neckline_design_labels
# 3  Images/neckline_design_labels/e948921d89da972c...  neckline_design_labels
# 4  Images/neckline_design_labels/6b81ca0da1970654...  neckline_design_labels
#
#         label
# 0  nnnnnynnnn
# 1  nnnnnnnynn
# 2  nnnnnnnynn
# 3  ynnnnnnnnn
# 4  nnnnnnynnn

# %%
n_ration=0.9
valid_data=df_load[int(n_ration*len(df_load)):]
df_load=df_load[:int(n_ration*len(df_load))]

# %%
mkdir_if_not_exist(['./data/round2/preprocessing/Images/{}/'.format(cur_class)])

# %% [markdown]
# ## 数据预处理

# %%
rootdir = './data/train/Images/{}'.format(cur_class)  # 指明被遍历的文件夹
m = 0
outdir = './data/round2/preprocessing/Images/{}/'.format(cur_class)

for parent, dirnames, filenames in os.walk(rootdir):
    for filename in filenames:
        currentPath = os.path.join(parent, filename)

        # 先填充, 再缩放
        img = cv2.imread(currentPath)
        dst0 = cv2.resize(img, (299, 299), interpolation=cv2.INTER_AREA)
        rows,cols,channels = dst0.shape

#         # 顺时针旋转 5°/ 放大 5%
#         M1 = cv2.getRotationMatrix2D((cols/2,rows/2),5,1) 
#         M2 = cv2.getRotationMatrix2D((cols/2,rows/2),0,1.05) 
#         dst1 = cv2.warpAffine(dst0,M1,(cols,rows))
#         dst2 = cv2.warpAffine(dst0,M2,(cols,rows))
        
#         # 向下平移 0.2
#         M3 = np.float32([[1,0,0],[0,1,int(cols*0.2)]])
#         dst3 = cv2.warpAffine(dst0,M3,(cols,rows))
        
        # 水平翻转
        dst1 = cv2.flip(dst0, 1)
        
        # 水平翻转+直方均衡
        dst2 = exposure.equalize_hist(img)*255
        
        # 对比拉伸
        p2, p98 = np.percentile(dst0, (2, 98))
        dst3 = exposure.rescale_intensity(dst0, in_range=(p2, p98))
        
#         # 对翻转后图片, 左右旋转 20°
#         M4 = cv2.getRotationMatrix2D((cols/2,rows/2),20,1)
#         M5 = cv2.getRotationMatrix2D((cols/2,rows/2),-20,1)
#         dst5 = cv2.warpAffine(dst4,M4,(cols,rows))
#         dst6 = cv2.warpAffine(dst4,M5,(cols,rows))
        
#         # 翻转后向下平移 0.2
#         M6 = np.float32([[1,0,0],[0,1,int(cols*0.2)]])
#         dst7 = cv2.warpAffine(dst4,M6,(cols,rows))
        
        cv2.imwrite(outdir + filename + "-0.jpg", dst0)
        cv2.imwrite(outdir + filename + "-1.jpg", dst1)
        cv2.imwrite(outdir + filename + "-2.jpg", dst2)
        cv2.imwrite(outdir + filename + "-3.jpg", dst3)
#         cv2.imwrite(outdir + filename + "-4.jpg", dst4.astype("uint8"))
#         cv2.imwrite(outdir + filename + "-5.jpg", dst5)
#         cv2.imwrite(outdir + filename + "-6.jpg", dst6)
#         cv2.imwrite(outdir + filename + "-7.jpg", dst7)
        m += 1
        if m%100 == 0:
            print('{} images have preprocessed.'.format(m))
# Out:
# 100 images have preprocessed.
# 200 images have preprocessed.
# 300 images have preprocessed.
# 400 images have preprocessed.
# 500 images have preprocessed.
# 600 images have preprocessed.
# 700 images have preprocessed.
# 800 images have preprocessed.
# 900 images have preprocessed.
# 1000 images have preprocessed.
# 1100 images have preprocessed.
# 1200 images have preprocessed.
# 1300 images have preprocessed.
# 1400 images have preprocessed.
# 1500 images have preprocessed.
# 1600 images have preprocessed.
# 1700 images have preprocessed.
# 1800 images have preprocessed.
# 1900 images have preprocessed.
# 2000 images have preprocessed.
# 2100 images have preprocessed.
# 2200 images have preprocessed.
# 2300 images have preprocessed.
# 2400 images have preprocessed.
# 2500 images have preprocessed.
# 2600 images have preprocessed.
# 2700 images have preprocessed.
# 2800 images have preprocessed.
# 2900 images have preprocessed.
# 3000 images have preprocessed.
# 3100 images have preprocessed.
# 3200 images have preprocessed.
# 3300 images have preprocessed.
# 3400 images have preprocessed.
# 3500 images have preprocessed.
# 3600 images have preprocessed.
# 3700 images have preprocessed.
# 3800 images have preprocessed.
# 3900 images have preprocessed.
# 4000 images have preprocessed.
# 4100 images have preprocessed.
# 4200 images have preprocessed.
# 4300 images have preprocessed.
# 4400 images have preprocessed.
# 4500 images have preprocessed.
# 4600 images have preprocessed.
# 4700 images have preprocessed.
# 4800 images have preprocessed.
# 4900 images have preprocessed.
# 5000 images have preprocessed.
# 5100 images have preprocessed.
# 5200 images have preprocessed.
# 5300 images have preprocessed.
# 5400 images have preprocessed.
# 5500 images have preprocessed.
# 5600 images have preprocessed.
# 5700 images have preprocessed.
# 5800 images have preprocessed.
# 5900 images have preprocessed.
# 6000 images have preprocessed.
# 6100 images have preprocessed.
# 6200 images have preprocessed.
# 6300 images have preprocessed.
# 6400 images have preprocessed.
# 6500 images have preprocessed.
# 6600 images have preprocessed.
# 6700 images have preprocessed.
# 6800 images have preprocessed.
# 6900 images have preprocessed.
# 7000 images have preprocessed.
# 7100 images have preprocessed.
# 7200 images have preprocessed.
# 7300 images have preprocessed.
# 7400 images have preprocessed.
# 7500 images have preprocessed.
# 7600 images have preprocessed.
# 7700 images have preprocessed.
# 7800 images have preprocessed.
# 7900 images have preprocessed.
# 8000 images have preprocessed.
# 8100 images have preprocessed.
# 8200 images have preprocessed.
# 8300 images have preprocessed.
# 8400 images have preprocessed.
# 8500 images have preprocessed.
# 8600 images have preprocessed.
# 8700 images have preprocessed.
# 8800 images have preprocessed.
# 8900 images have preprocessed.
# 9000 images have preprocessed.
# 9100 images have preprocessed.
# 9200 images have preprocessed.
# 9300 images have preprocessed.
# 9400 images have preprocessed.
# 9500 images have preprocessed.
# 9600 images have preprocessed.
# 9700 images have preprocessed.
# 9800 images have preprocessed.
# 9900 images have preprocessed.
# 10000 images have preprocessed.
# 10100 images have preprocessed.
# 10200 images have preprocessed.
# 10300 images have preprocessed.
# 10400 images have preprocessed.
# 10500 images have preprocessed.
# 10600 images have preprocessed.
# 10700 images have preprocessed.
# 10800 images have preprocessed.
# 10900 images have preprocessed.
# 11000 images have preprocessed.
# 11100 images have preprocessed.
# 11200 images have preprocessed.
# 11300 images have preprocessed.
# 11400 images have preprocessed.
# 11500 images have preprocessed.
# 11600 images have preprocessed.
# 11700 images have preprocessed.
# 11800 images have preprocessed.
# 11900 images have preprocessed.
# 12000 images have preprocessed.
# 12100 images have preprocessed.
# 12200 images have preprocessed.
# 12300 images have preprocessed.
# 12400 images have preprocessed.
# 12500 images have preprocessed.
# 12600 images have preprocessed.
# 12700 images have preprocessed.
# 12800 images have preprocessed.
# 12900 images have preprocessed.
# 13000 images have preprocessed.
# 13100 images have preprocessed.
# 13200 images have preprocessed.
# 13300 images have preprocessed.
# 13400 images have preprocessed.
# 13500 images have preprocessed.
# 13600 images have preprocessed.
# 13700 images have preprocessed.
# 13800 images have preprocessed.
# 13900 images have preprocessed.
# 14000 images have preprocessed.
# 14100 images have preprocessed.
# 14200 images have preprocessed.
# 14300 images have preprocessed.
# 14400 images have preprocessed.
# 14500 images have preprocessed.
# 14600 images have preprocessed.
# 14700 images have preprocessed.
# 14800 images have preprocessed.
# 14900 images have preprocessed.
# 15000 images have preprocessed.
# 15100 images have preprocessed.
# 15200 images have preprocessed.
# 15300 images have preprocessed.
# 15400 images have preprocessed.
# 15500 images have preprocessed.
# 15600 images have preprocessed.
# 15700 images have preprocessed.
# 15800 images have preprocessed.
# 15900 images have preprocessed.
# 16000 images have preprocessed.
# 16100 images have preprocessed.
# 16200 images have preprocessed.
# 16300 images have preprocessed.

# %% [markdown]
# ## 加载训练集

# %%
n = len(df_load)
n_class = len(df_load['label'][0])
width = 299 # 定义图片大小

# %%
X_train = np.zeros((n*3, width, width, 3), dtype=np.uint8)
y_train = np.zeros((n*3, n_class), dtype=np.uint8)

# %%
for i in tqdm(range(n)):
    tmp_label = df_load['label'][i]
#     if len(tmp_label) > n_class:
#         print(df_load['image_id'][i])
    for j in range(3):
        X_train[i*3+j] = cv2.resize(cv2.imread('./data/round2/preprocessing/{0}'.format(df_load['image_id'][i] + "-%s.jpg"%j)), (width, width))
        y_train[i*3+j][tmp_label.find('y')] = 1
# Out:
# 100%|██████████| 14738/14738 [01:05<00:00, 224.32it/s]

# %% [markdown]
# ## 加载验证集

# %%
n_valid = len(valid_data)
n_class = len(df_load['label'][0])
width = 299 # 定义图片大小

X_valid = np.zeros((n_valid*3, width, width, 3), dtype=np.uint8)
y_valid = np.zeros((n_valid*3, n_class), dtype=np.uint8)

# %%
# 重置索引
valid_data = valid_data.reset_index(drop=True)

# %%
for i in tqdm(range(n_valid)):
    tmp_label = valid_data['label'][i]
#     if len(tmp_label) > n_class:
#         print(df_load['image_id'][i])
    X_valid[i] = cv2.resize(cv2.imread('./data/train/{0}'.format(valid_data['image_id'][i])), (width, width))
    y_valid[i][tmp_label.find('y')] = 1
# Out:
# 100%|██████████| 1638/1638 [00:09<00:00, 164.63it/s]

# %%
X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((44214, 299, 299, 3), (44214, 10), (4914, 299, 299, 3), (4914, 10))

# %%
# 随机显示 8 张图片
plt.figure(figsize=(12, 7))
for i in range(8):
    random_index = random.randint(0, n-1)
    plt.subplot(2, 4, i+1)
    plt.imshow(X_train[random_index][:,:,::-1])
    plt.title(y_train[random_index])

# %% [markdown]
# ## 建立模型

# %%
from keras.layers import *
from keras.models import *
from keras.callbacks import *
from keras.optimizers import *
from keras.applications import *
from keras.regularizers import *
from keras.applications.inception_v3 import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
cnn_model = InceptionResNetV2(include_top=False, input_shape=(width, width, 3), weights='imagenet')
inputs = Input((width, width, 3))

x = inputs
x = Lambda(preprocess_input, name='preprocessing')(x)
x = cnn_model(x)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(n_class, activation='softmax', name='softmax')(x)

model = Model(inputs, x)

# %%
adam = Adam(lr=0.001)
prefix_cls = cur_class.split('_')[0]

# %%
model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.load_weights('./models/{}.best0516a_InceptionResNetV2_round1.h5'.format(prefix_cls))

# %%
checkpointer = ModelCheckpoint(filepath='./models/{0}.best0516b_InceptionResNetV2_round2.h5'.format(prefix_cls), verbose=1, 
                               save_best_only=True)

try:
    h = model.fit(X_train, y_train, batch_size=32, epochs=1, 
                  callbacks=[EarlyStopping(patience=3), checkpointer], 
                  shuffle=True, 
                  validation_data=(X_valid, y_valid))
except KeyboardInterrupt:
    print('KeyboardInterrupt')
# Out:
# Train on 44214 samples, validate on 4914 samples
# Epoch 1/1
# 44214/44214 [==============================] - 1509s 34ms/step - loss: 0.8532 - acc: 0.7125 - val_loss: 0.9165 - val_acc: 0.6862
#
# Epoch 00001: val_loss improved from inf to 0.91650, saving model to ./models/neckline.best0516b_InceptionResNetV2_round2.h5

# %%
# 学习率减小 50 倍
adam = Adam(lr=0.0001)

model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
checkpointer = ModelCheckpoint(filepath='./models/{0}.best0516b_InceptionResNetV2_round2.h5'.format(prefix_cls), verbose=1, 
                               save_best_only=True)

try:
    h = model.fit(X_train, y_train, batch_size=32, epochs=1, 
                  callbacks=[EarlyStopping(patience=3), checkpointer], 
                  shuffle=True, 
                  validation_data=(X_valid, y_valid))
except KeyboardInterrupt:
    print('KeyboardInterrupt')
# Out:
# Train on 44214 samples, validate on 4914 samples
# Epoch 1/1
# 44214/44214 [==============================] - 1522s 34ms/step - loss: 0.2960 - acc: 0.8999 - val_loss: 0.6876 - val_acc: 0.7853
#
# Epoch 00001: val_loss improved from inf to 0.68758, saving model to ./models/neckline.best0516b_InceptionResNetV2_round2.h5

# %%
# 测试模型
# model.evaluate(X_valid, y_valid, batch_size=256)

# %% [markdown]
# ## 混淆矩阵

# %%
## sleeve: 0.7452

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This fuction prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalize=True'
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# Predict the values from the validation dataset
Y_pred = model.predict(X_valid)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis=1)
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_valid, axis=1)
# Compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
# plt the confusion matrix
plot_confusion_matrix(confusion_mtx, classes=range(n_class))

# %%
## skirt: 0.7073

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This fuction prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalize=True'
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# Predict the values from the validation dataset
Y_pred = model.predict(X_valid)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis=1)
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_valid, axis=1)
# Compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
# plt the confusion matrix
plot_confusion_matrix(confusion_mtx, classes=range(n_class))

# %%
## lapel: 0.7057

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This fuction prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalize=True'
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# Predict the values from the validation dataset
Y_pred = model.predict(X_valid)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis=1)
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_valid, axis=1)
# Compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
# plt the confusion matrix
plot_confusion_matrix(confusion_mtx, classes=range(n_class))

# %%
## coat: 0.6141

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This fuction prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalize=True'
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# Predict the values from the validation dataset
Y_pred = model.predict(X_valid)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis=1)
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_valid, axis=1)
# Compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
# plt the confusion matrix
plot_confusion_matrix(confusion_mtx, classes=range(n_class))

# %%
## neck: 0.7092

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This fuction prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalize=True'
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# Predict the values from the validation dataset
Y_pred = model.predict(X_valid)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis=1)
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_valid, axis=1)
# Compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
# plt the confusion matrix
plot_confusion_matrix(confusion_mtx, classes=range(n_class))

# %% [markdown]
# ## 测试集数据预处理

# %%
mkdir_if_not_exist(['./data/test-preprocessing/Images/{}/'.format(cur_class)])

# %%
rootdir = './data/week-rank/Images/{}'.format(cur_class)  # 指明被遍历的文件夹
m = 0
outdir = './data/test-preprocessing/Images/{}/'.format(cur_class)

for parent, dirnames, filenames in os.walk(rootdir):
    for filename in filenames:
        currentPath = os.path.join(parent, filename)

        # 先填充, 再缩放
        img = cv2.imread(currentPath)
        dst0 = cv2.resize(img, (299, 299), interpolation=cv2.INTER_AREA)
        rows,cols,channels = dst0.shape

#         # 顺时针旋转 5°/ 放大 5%
#         M1 = cv2.getRotationMatrix2D((cols/2,rows/2),5,1) 
#         M2 = cv2.getRotationMatrix2D((cols/2,rows/2),0,1.05) 
#         dst1 = cv2.warpAffine(dst0,M1,(cols,rows))
#         dst2 = cv2.warpAffine(dst0,M2,(cols,rows))
        
#         # 向下平移 0.2
#         M3 = np.float32([[1,0,0],[0,1,int(cols*0.2)]])
#         dst3 = cv2.warpAffine(dst0,M3,(cols,rows))
        
        # 水平翻转
        dst1 = cv2.flip(dst0, 1)
        
        # 高斯噪声
        dst0.astype("float")
        Gauss_noise = np.random.normal(0, 20, (rows, cols, channels))
        dst2 = dst0 + Gauss_noise
        dst2 = np.where(dst2 < 0, 0, np.where(dst2 > 255, 255, dst2))
        
#         # 对翻转后图片, 左右旋转 20°
#         M4 = cv2.getRotationMatrix2D((cols/2,rows/2),20,1)
#         M5 = cv2.getRotationMatrix2D((cols/2,rows/2),-20,1)
#         dst5 = cv2.warpAffine(dst4,M4,(cols,rows))
#         dst6 = cv2.warpAffine(dst4,M5,(cols,rows))
        
#         # 翻转后向下平移 0.2
#         M6 = np.float32([[1,0,0],[0,1,int(cols*0.2)]])
#         dst7 = cv2.warpAffine(dst4,M6,(cols,rows))
        
        cv2.imwrite(outdir + filename + "-0.jpg", dst0)
        cv2.imwrite(outdir + filename + "-1.jpg", dst1)
        cv2.imwrite(outdir + filename + "-2.jpg", dst2.astype("uint8"))
#         cv2.imwrite(outdir + filename + "-3.jpg", dst3)
#         cv2.imwrite(outdir + filename + "-4.jpg", dst4.astype("uint8"))
#         cv2.imwrite(outdir + filename + "-5.jpg", dst5)
#         cv2.imwrite(outdir + filename + "-6.jpg", dst6)
#         cv2.imwrite(outdir + filename + "-7.jpg", dst7)
        m += 1
        if m%100 == 0:
            print('{} images have preprocessed.'.format(m))
# Out:
# 100 images have preprocessed.
# 200 images have preprocessed.
# 300 images have preprocessed.
# 400 images have preprocessed.
# 500 images have preprocessed.
# 600 images have preprocessed.
# 700 images have preprocessed.
# 800 images have preprocessed.
# 900 images have preprocessed.
# 1000 images have preprocessed.
# 1100 images have preprocessed.
# 1200 images have preprocessed.
# 1300 images have preprocessed.
# 1400 images have preprocessed.
# 1500 images have preprocessed.
# 1600 images have preprocessed.
# 1700 images have preprocessed.
# 1800 images have preprocessed.
# 1900 images have preprocessed.
# 2000 images have preprocessed.
# 2100 images have preprocessed.
# 2200 images have preprocessed.
# 2300 images have preprocessed.
# 2400 images have preprocessed.
# 2500 images have preprocessed.
# 2600 images have preprocessed.
# 2700 images have preprocessed.

# %% [markdown]
# ## 预处理图片进行全部预测

# %%
df_test = pd.read_csv('./data/week-rank/Tests/question.csv', header=None)
df_test.columns = ['image_id', 'class', 'x']
del df_test['x']
df_test.head()
# Out:
#                                             image_id                 class
# 0  Images/collar_design_labels/1078bc9a4fa91aef69...  collar_design_labels
# 1  Images/collar_design_labels/272c5d069581efc94f...  collar_design_labels
# 2  Images/collar_design_labels/2e67922d82216cc756...  collar_design_labels
# 3  Images/collar_design_labels/d9726ceee17c7ee811...  collar_design_labels
# 4  Images/collar_design_labels/1b7de7f9def99a5aa6...  collar_design_labels

# %%
df_load2 = df_test[(df_test['class'] == cur_class)].copy()
df_load2.reset_index(inplace=True)
del df_load2['index']

print('{0}: {1}'.format(cur_class, len(df_load2)))
df_load2.head()
# Out:
# neckline_design_labels: 2714
#                                             image_id                   class
# 0  Images/neckline_design_labels/89d6bd83152ca94c...  neckline_design_labels
# 1  Images/neckline_design_labels/509a05b283b7d0fe...  neckline_design_labels
# 2  Images/neckline_design_labels/b2971f75a2bc83f6...  neckline_design_labels
# 3  Images/neckline_design_labels/7393a3c475d093e5...  neckline_design_labels
# 4  Images/neckline_design_labels/8bd6af5d69406b44...  neckline_design_labels

# %%
n = len(df_load2)
width = 299 # 定义图片大小
X_test = np.zeros((n*3, width, width, 3), dtype=np.uint8)

for i in tqdm(range(n)):
    for j in range(3):
        X_test[i*3+j] = cv2.resize(cv2.imread('./data/test-preprocessing/{0}'.format(df_load2['image_id'][i] + "-%s.jpg"%j)), (width, width))
# Out:
# 100%|██████████| 2714/2714 [00:11<00:00, 233.34it/s]

# %%
# model.load_weights('./models/{}.best0515a_InceptionResNetV2.h5'.format(prefix_cls))

# %%
test_np = model.predict(X_test, batch_size=256)

# %%
# 取同一张图片不同预处理方式的平均值
result = []

for i, row in df_load2.iterrows():
    tmp_list = (test_np[i*3+0] + test_np[i*3+1] + test_np[i*3+2])/3
    tmp_result = ''
    for tmp_ret in tmp_list:
        tmp_result += '{:.4f};'.format(tmp_ret)
        
    result.append(tmp_result[:-1])

df_load2['result'] = result
df_load2.head()
# Out:
#                                             image_id                   class  \
# 0  Images/neckline_design_labels/89d6bd83152ca94c...  neckline_design_labels
# 1  Images/neckline_design_labels/509a05b283b7d0fe...  neckline_design_labels
# 2  Images/neckline_design_labels/b2971f75a2bc83f6...  neckline_design_labels
# 3  Images/neckline_design_labels/7393a3c475d093e5...  neckline_design_labels
# 4  Images/neckline_design_labels/8bd6af5d69406b44...  neckline_design_labels
#
#                                               result
# 0  0.0010;0.0000;0.0058;0.0000;0.9921;0.0000;0.00...
# 1  0.0002;0.0009;0.0001;0.0000;0.0005;0.0003;0.00...
# 2  0.0058;0.0000;0.9899;0.0000;0.0041;0.0000;0.00...
# 3  0.0002;0.0046;0.0000;0.0000;0.0000;0.0001;0.00...
# 4  0.3373;0.0002;0.0013;0.0003;0.6194;0.0002;0.00...

# %%
df_load2.to_csv('./result/{}_0516a_InceptionResNetV2.csv'.format(prefix_cls), header=None, index=False)
