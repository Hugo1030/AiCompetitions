# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('S2_feature_name.csv')

# %%
#用于select 语句的列
def col_name(data):
    list_col=[]
    for i in data:
        print(i+',')

# %%
#用于生成PAI命令行需要输入的Feature列
def col_name_without_space(data):
    list_col=[]
    ss=''
    for i in data:
        list_col.append(i)
    for i in list_col:
        ss=ss+i+','
    print(ss)

# %%
def x_col_name(data,x):
    list_col=[]
    for i in data:
        print('%s.'%x+i+',')

# %%
col_name(data)
# Out:
# class_id,
# power_max,
# power_min,
# power_avg,
# car_length_max,
# car_length_min,
# car_length_avg,
# car_width_max,
# car_width_min,
# car_width_avg,
# car_height_max,
# car_height_min,
# car_height_avg,
# total_quality_max,
# total_quality_min,
# total_quality_avg,
# equipment_quality_max,
# equipment_quality_min,
# equipment_quality_avg,
# wheelbase_max,
# wheelbase_min,
# wheelbase_avg,
# front_track_max,
# front_track_min,
# front_track_avg,
# rear_track_max,
# rear_track_min,
# rear_track_avg,
# price_level_max,
# price_level_min,
# price_level_avg,
# displacement_max,
# displacement_min,
# displacement_avg,
# rated_passenger_max,
# rated_passenger_min,
# rated_passenger_avg,
# brand_id_15,
# brand_id_18,
# brand_id_21,
# brand_id_27,
# brand_id_30,
# brand_id_36,
# brand_id_39,
# brand_id_42,
# brand_id_48,
# brand_id_57,
# brand_id_60,
# brand_id_63,
# brand_id_66,
# brand_id_69,
# brand_id_84,
# brand_id_99,
# brand_id_102,
# brand_id_108,
# brand_id_117,
# brand_id_123,
# ...

# %%
col_name_without_space(data1)
# Out:
# sale_date,province_id,city_id,class_id,sale_quantity,oil_price,total_sale_last1m,total_last12m_sum,sale_last1m,sale_last12m,sale_last12m_sum,cnt_classid,year,month,power_max,power_min,power_avg,car_length_max,car_length_min,car_length_avg,car_width_max,car_width_min,car_width_avg,car_height_max,car_height_min,car_height_avg,total_quality_max,total_quality_min,total_quality_avg,equipment_quality_max,equipment_quality_min,equipment_quality_avg,wheelbase_max,wheelbase_min,wheelbase_avg,front_track_max,front_track_min,front_track_avg,rear_track_max,rear_track_min,rear_track_avg,price_level_max,price_level_min,price_level_avg,displacement_max,displacement_min,displacement_avg,rated_passenger_max,rated_passenger_min,rated_passenger_avg,brand_id_15,brand_id_18,brand_id_21,brand_id_27,brand_id_30,brand_id_36,brand_id_39,brand_id_42,brand_id_48,brand_id_57,brand_id_60,brand_id_63,brand_id_66,brand_id_69,brand_id_84,brand_id_99,brand_id_102,brand_id_108,brand_id_117,brand_id_123,brand_id_126,b
# ...

# %%
data3=pd.read_csv('ycc_sales_lichuan0307_trainset_1_time_window_head.csv')

# %%
col_name_without_space(data3)
# Out:
# sale_date,province_id,city_id,class_id,sale_quantity,oil_price,total_sale_last1m,total_last12m_sum,sale_last1m,sale_last12m,cnt_classid,year,month,how_many_month_sale,purchase_tax,sale_last2m_sum,sale_last3m_sum,sale_last6m_sum,sale_last12m_sum,sale_last2m_std,sale_last3m_std,sale_last6m_std,sale_last12m_std,sale_last2m_avg,sale_last3m_avg,sale_last6m_avg,sale_last12m_avg,lastyear_mom,max2m,max3m,max6m,max12m,min2m,min3m,min6m,min12m,power_max,power_min,power_avg,car_length_max,car_length_min,car_length_avg,car_width_max,car_width_min,car_width_avg,car_height_max,car_height_min,car_height_avg,total_quality_max,total_quality_min,total_quality_avg,equipment_quality_max,equipment_quality_min,equipment_quality_avg,wheelbase_max,wheelbase_min,wheelbase_avg,front_track_max,front_track_min,front_track_avg,rear_track_max,rear_track_min,rear_track_avg,price_level_max,price_level_min,price_level_avg,displacement_max,displacement_min,displacement_avg,rated_passenger_max,rated_passenger_min,rate
# ...

# %%
ls
# Out:
# S2_feature_month_name.csv
# S2_feature_name.csv
# S2_province_sale_quantity.xlsx
# S2训练数据表现.xlsx
# S2全国各月产量销量表.csv
# result_180223_baseline*0.7_lightGBM*0.3.csv
# result_180224_baseline*0.5_lightGBM*0.3_lstm*0.2.csv
# result_180224_baseline*0.5_lightGBM*0.5.csv
# result_180226_GBDT.csv
# result_180226_gbdt*0.5_xgb*0.5.csv
# result_180226_gbdt_big_quantity*1.5.csv
# result_20180209_xgboost-allfeatures*0.5-baseline*0.5*1.1.csv
# result_20180209_xgboost-allfeatures.csv
# result_woody20180204_1.csv
# result_woody20180204_2.csv
# result_woody20180206_1
# result_woody20180206_1.csv
# s2_woody_lichuan0307_feature_13_time_window_head.csv
# ycc_sales_lichuan0307_feature_14_max_min.csv
# ycc_sales_lichuan0307_feature_3_change_double.csv
# ycc_sales_lichuan0307_trainset_1_time_window_head.csv

# %%
data=pd.read_csv('ycc_sales_lichuan0307_feature_14_max_min.csv');
data2=pd.read_csv('ycc_sales_lichuan0307_feature_3_change_double.csv')

# %%
col_name(data)
# Out:
# sale_date,
# province_id,
# city_id,
# class_id,
# sale_quantity,
# oil_price,
# total_sale_last1m,
# total_last12m_sum,
# sale_last1m,
# sale_last12m,
# cnt_classid,
# year,
# month,
# how_many_month_sale,
# purchase_tax,
# sale_last2m_sum,
# sale_last3m_sum,
# sale_last6m_sum,
# sale_last12m_sum,
# sale_last2m_std,
# sale_last3m_std,
# sale_last6m_std,
# sale_last12m_std,
# sale_last2m_avg,
# sale_last3m_avg,
# sale_last6m_avg,
# sale_last12m_avg,
# max2m,
# max3m,
# max6m,
# max12m,
# min2m,
# min3m,
# min6m,
# min12m,
# lastyear_mom,

# %%
col_name(data2)
# Out:
# class_id,
# power_max,
# power_min,
# power_avg,
# car_length_max,
# car_length_min,
# car_length_avg,
# car_width_max,
# car_width_min,
# car_width_avg,
# car_height_max,
# car_height_min,
# car_height_avg,
# total_quality_max,
# total_quality_min,
# total_quality_avg,
# equipment_quality_max,
# equipment_quality_min,
# equipment_quality_avg,
# wheelbase_max,
# wheelbase_min,
# wheelbase_avg,
# front_track_max,
# front_track_min,
# front_track_avg,
# rear_track_max,
# rear_track_min,
# rear_track_avg,
# price_level_max,
# price_level_min,
# price_level_avg,
# displacement_max,
# displacement_min,
# displacement_avg,
# rated_passenger_max,
# rated_passenger_min,
# rated_passenger_avg,
# brand_id_15,
# brand_id_18,
# brand_id_21,
# brand_id_27,
# brand_id_30,
# brand_id_36,
# brand_id_39,
# brand_id_42,
# brand_id_48,
# brand_id_57,
# brand_id_60,
# brand_id_63,
# brand_id_66,
# brand_id_69,
# brand_id_84,
# brand_id_99,
# brand_id_102,
# brand_id_108,
# brand_id_117,
# brand_id_123,
# ...

# %%
x_col_name(data,'a')
# Out:
# a.sale_date,
# a.province_id,
# a.city_id,
# a.class_id,
# a.sale_quantity,
# a.oil_price,
# a.total_sale_last1m,
# a.total_last12m_sum,
# a.sale_last1m,
# a.sale_last12m,
# a.cnt_classid,
# a.year,
# a.month,
# a.how_many_month_sale,
# a.purchase_tax,
# a.sale_last2m_sum,
# a.sale_last3m_sum,
# a.sale_last6m_sum,
# a.sale_last12m_sum,
# a.sale_last2m_std,
# a.sale_last3m_std,
# a.sale_last6m_std,
# a.sale_last12m_std,
# a.sale_last2m_avg,
# a.sale_last3m_avg,
# a.sale_last6m_avg,
# a.sale_last12m_avg,
# a.max2m,
# a.max3m,
# a.max6m,
# a.max12m,
# a.min2m,
# a.min3m,
# a.min6m,
# a.min12m,
# a.lastyear_mom,

# %%
ls
# Out:
# S2_feature_month_name.csv
# S2_feature_name.csv
# S2_province_sale_quantity.xlsx
# S2训练数据表现.xlsx
# S2全国各月产量销量表.csv
# result_180223_baseline*0.7_lightGBM*0.3.csv
# result_180224_baseline*0.5_lightGBM*0.3_lstm*0.2.csv
# result_180224_baseline*0.5_lightGBM*0.5.csv
# result_180226_GBDT.csv
# result_180226_gbdt*0.5_xgb*0.5.csv
# result_180226_gbdt_big_quantity*1.5.csv
# result_20180209_xgboost-allfeatures*0.5-baseline*0.5*1.1.csv
# result_20180209_xgboost-allfeatures.csv
# result_woody20180204_1.csv
# result_woody20180204_2.csv
# result_woody20180206_1
# result_woody20180206_1.csv
# s2_woody_lichuan0307_feature_13_time_window_head.csv
# stuff_woody_0310_max_min_window.csv
# stuff_woody_0310_max_min_window.xlsx
# ycc_sales_lichuan0307_feature_14_max_min.csv
# ycc_sales_lichuan0307_feature_3_change_double.csv
# ycc_sales_lichuan0307_trainset_1_time_window_head.csv
# ycc_sales_lichuan0307_traintest_1_time_window.csv

# %%
data4=pd.read_csv('stuff_woody_0310_max_min_window.csv')
col_name_without_space(data4)
# Out:
# sale_date,province_id,city_id,class_id,sale_quantity,oil_price,total_sale_last1m,total_last12m_sum,sale_last1m,sale_last12m,cnt_classid,year,month,how_many_month_sale,purchase_tax,sale_last2m_sum,sale_last3m_sum,sale_last6m_sum,sale_last12m_sum,sale_last2m_std,sale_last3m_std,sale_last6m_std,sale_last12m_std,sale_last2m_avg,sale_last3m_avg,sale_last6m_avg,sale_last12m_avg,lastyear_mom,power_max,power_min,max2m,max3m,max6m,max12m,min2m,min3m,min6m,min12m,power_avg,car_length_max,car_length_min,car_length_avg,car_width_max,car_width_min,car_width_avg,car_height_max,car_height_min,car_height_avg,total_quality_max,total_quality_min,total_quality_avg,equipment_quality_max,equipment_quality_min,equipment_quality_avg,wheelbase_max,wheelbase_min,wheelbase_avg,front_track_max,front_track_min,front_track_avg,rear_track_max,rear_track_min,rear_track_avg,price_level_max,price_level_min,price_level_avg,displacement_max,displacement_min,displacement_avg,rated_passenger_max,rated_passenger_min,rate
# ...

# %%
sale_date,province_id,city_id,class_id,sale_quantity,oil_price,total_sale_last1m,total_last12m_sum,sale_last1m,sale_last12m,cnt_classid,year,month,how_many_month_sale,purchase_tax,sale_last2m_sum,sale_last3m_sum,sale_last6m_sum,sale_last12m_sum,sale_last2m_std,sale_last3m_std,sale_last6m_std,sale_last12m_std,sale_last2m_avg,sale_last3m_avg,sale_last6m_avg,sale_last12m_avg,lastyear_mom,power_max,power_min,max2m,max3m,max6m,max12m,min2m,min3m,min6m,min12m,power_avg,car_length_max,car_length_min,car_length_avg,car_width_max,car_width_min,car_width_avg,car_height_max,car_height_min,car_height_avg,total_quality_max,total_quality_min,total_quality_avg,equipment_quality_max,equipment_quality_min,equipment_quality_avg,wheelbase_max,wheelbase_min,wheelbase_avg,front_track_max,front_track_min,front_track_avg,rear_track_max,rear_track_min,rear_track_avg,price_level_max,price_level_min,price_level_avg,displacement_max,displacement_min,displacement_avg,rated_passenger_max,rated_passenger_min,rated_passenger_avg,brand_id_15,brand_id_18,brand_id_21,brand_id_27,brand_id_30,brand_id_36,brand_id_39,brand_id_42,brand_id_48,brand_id_57,brand_id_60,brand_id_63,brand_id_66,brand_id_69,brand_id_84,brand_id_99,brand_id_102,brand_id_108,brand_id_117,brand_id_123,brand_id_126,brand_id_129,brand_id_132,brand_id_135,brand_id_138,brand_id_141,brand_id_165,brand_id_225,brand_id_237,brand_id_10,brand_id_13,brand_id_16,brand_id_22,brand_id_25,brand_id_28,brand_id_31,brand_id_34,brand_id_37,brand_id_43,brand_id_46,brand_id_49,brand_id_52,brand_id_55,brand_id_58,brand_id_67,brand_id_79,brand_id_82,brand_id_91,brand_id_94,brand_id_100,brand_id_103,brand_id_109,brand_id_121,brand_id_127,brand_id_130,brand_id_133,brand_id_139,brand_id_142,brand_id_145,brand_id_187,brand_id_223,brand_id_229,brand_id_232,brand_id_235,brand_id_238,brand_id_2,brand_id_8,brand_id_11,brand_id_14,brand_id_17,brand_id_23,brand_id_29,brand_id_32,brand_id_35,brand_id_38,brand_id_41,brand_id_47,brand_id_50,brand_id_53,brand_id_56,brand_id_59,brand_id_65,brand_id_68,brand_id_77,brand_id_80,brand_id_83,brand_id_86,brand_id_95,brand_id_98,brand_id_101,brand_id_104,brand_id_110,brand_id_122,brand_id_125,brand_id_134,brand_id_137,brand_id_140,brand_id_143,brand_id_173,brand_id_185,brand_id_200,brand_id_209,brand_id_221,brand_id_227,brand_id_230,brand_id_233,brand_id_236,brand_id_239,brand_id_245,compartment_1,compartment_2,compartment_3,type_id_1,type_id_2,type_id_3,type_id_4,level_id_0,level_id_1,level_id_2,level_id_3,level_id_4,level_id_5,level_id_6,level_id_7,department_id_0,department_id_1,department_id_2,department_id_3,department_id_4,department_id_5,tr_0,tr_1,tr_1_2,tr_2,tr_4,tr_4_5,tr_4_6,tr_5,tr_5_0,tr_5_4,tr_5_6,tr_5_7,tr_6,tr_6_0,tr_6_7,tr_7,tr_8,tr_8_0,tr_8_7,tr_9,gearbox_type_amt,gearbox_type_at,gearbox_type_at_cvt,gearbox_type_at_dct,gearbox_type_cvt,gearbox_type_dct,gearbox_type_mt,gearbox_type_mt_amt,gearbox_type_mt_at,gearbox_type_mt_cvt,if_charging_l,if_charging_t,driven_type_id_0,driven_type_id_1,driven_type_id_2,driven_type_id_3,fuel_type_id_0,fuel_type_id_1,fuel_type_id_2,fuel_type_id_3,fuel_type_id_4,newenergy_type_id_0,newenergy_type_id_1,newenergy_type_id_2,newenergy_type_id_3,newenergy_type_id_4,emission_standards_id_0,emission_standards_id_1,emission_standards_id_2,emission_standards_id_3,emission_standards_id_4,if_mpv_id,if_luxurious_id,cylinder_number_0,cylinder_number_3,cylinder_number_4,cylinder_number_5,cylinder_number_6,cylinder_number_8,cylinder_number_12

# %%
ls
# Out:
# S2_feature_month_name.csv
# S2_feature_name.csv
# S2_province_sale_quantity.xlsx
# S2训练数据表现.xlsx
# S2全国各月产量销量表.csv
# result_180223_baseline*0.7_lightGBM*0.3.csv
# result_180224_baseline*0.5_lightGBM*0.3_lstm*0.2.csv
# result_180224_baseline*0.5_lightGBM*0.5.csv
# result_180226_GBDT.csv
# result_180226_gbdt*0.5_xgb*0.5.csv
# result_180226_gbdt_big_quantity*1.5.csv
# result_20180209_xgboost-allfeatures*0.5-baseline*0.5*1.1.csv
# result_20180209_xgboost-allfeatures.csv
# result_woody20180204_1.csv
# result_woody20180204_2.csv
# result_woody20180206_1
# result_woody20180206_1.csv
# s2_woody_lichuan0307_feature_13_time_window_head.csv
# stuff_woody_0310_max_min_window.csv
# stuff_woody_0310_max_min_window.xlsx
# ycc_sales_lichuan0307_feature_14_max_min.csv
# ycc_sales_lichuan0307_feature_16_produce_quantity.csv
# ycc_sales_lichuan0307_feature_3_change_double.csv
# ycc_sales_lichuan0307_trainset_1_time_window_head.csv
# ycc_sales_lichuan0307_traintest_1_time_window.csv

# %%
data1=pd.read_csv('ycc_sales_lichuan0307_feature_16_produce_quantity.csv')

# %%
x_col_name(data4,'a')
# Out:
# a.sale_date,
# a.province_id,
# a.city_id,
# a.class_id,
# a.sale_quantity,
# a.oil_price,
# a.total_sale_last1m,
# a.total_last12m_sum,
# a.sale_last1m,
# a.sale_last12m,
# a.cnt_classid,
# a.year,
# a.month,
# a.how_many_month_sale,
# a.purchase_tax,
# a.sale_last2m_sum,
# a.sale_last3m_sum,
# a.sale_last6m_sum,
# a.sale_last12m_sum,
# a.sale_last2m_std,
# a.sale_last3m_std,
# a.sale_last6m_std,
# a.sale_last12m_std,
# a.sale_last2m_avg,
# a.sale_last3m_avg,
# a.sale_last6m_avg,
# a.sale_last12m_avg,
# a.lastyear_mom,
# a.power_max,
# a.power_min,
# a.max2m,
# a.max3m,
# a.max6m,
# a.max12m,
# a.min2m,
# a.min3m,
# a.min6m,
# a.min12m,
# a.power_avg,
# a.car_length_max,
# a.car_length_min,
# a.car_length_avg,
# a.car_width_max,
# a.car_width_min,
# a.car_width_avg,
# a.car_height_max,
# a.car_height_min,
# a.car_height_avg,
# a.total_quality_max,
# a.total_quality_min,
# a.total_quality_avg,
# a.equipment_quality_max,
# a.equipment_quality_min,
# a.equipment_quality_avg,
# ...

# %%
x_col_name(data1,'b')
# Out:
# b.sale_date,
# b.province_id,
# b.city_id,
# b.class_id,
# b.sale_quantity,
# b.oil_price,
# b.total_sale_last1m,
# b.total_last12m_sum,
# b.sale_last1m,
# b.sale_last12m,
# b.cnt_classid,
# b.year,
# b.month,
# b.how_many_month_sale,
# b.purchase_tax,
# b.sale_last2m_sum,
# b.sale_last3m_sum,
# b.sale_last6m_sum,
# b.sale_last12m_sum,
# b.sale_last2m_std,
# b.sale_last3m_std,
# b.sale_last6m_std,
# b.sale_last12m_std,
# b.sale_last2m_avg,
# b.sale_last3m_avg,
# b.sale_last6m_avg,
# b.sale_last12m_avg,
# b.max2m,
# b.max3m,
# b.max6m,
# b.max12m,
# b.min2m,
# b.min3m,
# b.min6m,
# b.min12m,
# b.lastyear_mom,
# b.spring_festival,
# b.produce_quantity_last1m,

# %%
data5=pd.read_csv('ycc_sales_lichuan0312_feature_16_produce_quantity_shift1m.csv')

# %%
col_name(data5)
# Out:
# sale_date,
# province_id,
# city_id,
# class_id,
# sale_quantity,
# oil_price,
# total_sale_last1m,
# total_last12m_sum,
# sale_last1m,
# sale_last12m,
# cnt_classid,
# year,
# month,
# how_many_month_sale,
# purchase_tax,
# sale_last2m_sum,
# sale_last3m_sum,
# sale_last6m_sum,
# sale_last12m_sum,
# sale_last2m_std,
# sale_last3m_std,
# sale_last6m_std,
# sale_last12m_std,
# sale_last2m_avg,
# sale_last3m_avg,
# sale_last6m_avg,
# sale_last12m_avg,
# max2m,
# max3m,
# max6m,
# max12m,
# min2m,
# min3m,
# min6m,
# min12m,
# lastyear_mom,
# spring_festival,
# produce_quantity_last1m,

# %%
x_col_name(data5,'b')
# Out:
# b.sale_date,
# b.province_id,
# b.city_id,
# b.class_id,
# b.sale_quantity,
# b.oil_price,
# b.total_sale_last1m,
# b.total_last12m_sum,
# b.sale_last1m,
# b.sale_last12m,
# b.cnt_classid,
# b.year,
# b.month,
# b.how_many_month_sale,
# b.purchase_tax,
# b.sale_last2m_sum,
# b.sale_last3m_sum,
# b.sale_last6m_sum,
# b.sale_last12m_sum,
# b.sale_last2m_std,
# b.sale_last3m_std,
# b.sale_last6m_std,
# b.sale_last12m_std,
# b.sale_last2m_avg,
# b.sale_last3m_avg,
# b.sale_last6m_avg,
# b.sale_last12m_avg,
# b.max2m,
# b.max3m,
# b.max6m,
# b.max12m,
# b.min2m,
# b.min3m,
# b.min6m,
# b.min12m,
# b.lastyear_mom,
# b.spring_festival,
# b.produce_quantity_last1m,

# %%
sale_date,
province_id,
city_id,
class_id,
sale_quantity,
oil_price,
total_sale_last1m,
total_sale_last1m,
total_sale_last1m,
total_sale_last1m,
total_last12m_sum,
sale_last1m,
sale_last12m,
cnt_classid,
year,
month,
how_many_month_sale,
purchase_tax,
sale_last2m_sum,
sale_last3m_sum,
sale_last6m_sum,
sale_last12m_sum,
sale_last2m_std,
sale_last3m_std,
sale_last6m_std,
sale_last12m_std,
sale_last2m_avg,
sale_last3m_avg,
sale_last6m_avg,
sale_last12m_avg,
max2m,
max3m,
max6m,
max12m,
min2m,
min3m,
min6m,
min12m,
lastyear_mom,
spring_festival,
produce_quantity_last1m,

# %%
def col_name_x(data,x):
    list_col=[]
    for i in data:
        print(i+'%s'%x+',')

# %%
col_name_x(data5,'_add')
# Out:
# sale_date_add,
# province_id_add,
# city_id_add,
# class_id_add,
# sale_quantity_add,
# oil_price_add,
# total_sale_last1m_add,
# total_last12m_sum_add,
# sale_last1m_add,
# sale_last12m_add,
# cnt_classid_add,
# year_add,
# month_add,
# how_many_month_sale_add,
# purchase_tax_add,
# sale_last2m_sum_add,
# sale_last3m_sum_add,
# sale_last6m_sum_add,
# sale_last12m_sum_add,
# sale_last2m_std_add,
# sale_last3m_std_add,
# sale_last6m_std_add,
# sale_last12m_std_add,
# sale_last2m_avg_add,
# sale_last3m_avg_add,
# sale_last6m_avg_add,
# sale_last12m_avg_add,
# max2m_add,
# max3m_add,
# max6m_add,
# max12m_add,
# min2m_add,
# min3m_add,
# min6m_add,
# min12m_add,
# lastyear_mom_add,
# spring_festival_add,
# produce_quantity_last1m_add,

# %%
col_name_x(data5,'_minus')
# Out:
# sale_date_minus,
# province_id_minus,
# city_id_minus,
# class_id_minus,
# sale_quantity_minus,
# oil_price_minus,
# total_sale_last1m_minus,
# total_last12m_sum_minus,
# sale_last1m_minus,
# sale_last12m_minus,
# cnt_classid_minus,
# year_minus,
# month_minus,
# how_many_month_sale_minus,
# purchase_tax_minus,
# sale_last2m_sum_minus,
# sale_last3m_sum_minus,
# sale_last6m_sum_minus,
# sale_last12m_sum_minus,
# sale_last2m_std_minus,
# sale_last3m_std_minus,
# sale_last6m_std_minus,
# sale_last12m_std_minus,
# sale_last2m_avg_minus,
# sale_last3m_avg_minus,
# sale_last6m_avg_minus,
# sale_last12m_avg_minus,
# max2m_minus,
# max3m_minus,
# max6m_minus,
# max12m_minus,
# min2m_minus,
# min3m_minus,
# min6m_minus,
# min12m_minus,
# lastyear_mom_minus,
# spring_festival_minus,
# produce_quantity_last1m_minus,

# %%
col_name_x(data5,'_mul')
# Out:
# sale_date_mul,
# province_id_mul,
# city_id_mul,
# class_id_mul,
# sale_quantity_mul,
# oil_price_mul,
# total_sale_last1m_mul,
# total_last12m_sum_mul,
# sale_last1m_mul,
# sale_last12m_mul,
# cnt_classid_mul,
# year_mul,
# month_mul,
# how_many_month_sale_mul,
# purchase_tax_mul,
# sale_last2m_sum_mul,
# sale_last3m_sum_mul,
# sale_last6m_sum_mul,
# sale_last12m_sum_mul,
# sale_last2m_std_mul,
# sale_last3m_std_mul,
# sale_last6m_std_mul,
# sale_last12m_std_mul,
# sale_last2m_avg_mul,
# sale_last3m_avg_mul,
# sale_last6m_avg_mul,
# sale_last12m_avg_mul,
# max2m_mul,
# max3m_mul,
# max6m_mul,
# max12m_mul,
# min2m_mul,
# min3m_mul,
# min6m_mul,
# min12m_mul,
# lastyear_mom_mul,
# spring_festival_mul,
# produce_quantity_last1m_mul,

# %%
col_name_x(data5,'_div')
# Out:
# sale_date_div,
# province_id_div,
# city_id_div,
# class_id_div,
# sale_quantity_div,
# oil_price_div,
# total_sale_last1m_div,
# total_last12m_sum_div,
# sale_last1m_div,
# sale_last12m_div,
# cnt_classid_div,
# year_div,
# month_div,
# how_many_month_sale_div,
# purchase_tax_div,
# sale_last2m_sum_div,
# sale_last3m_sum_div,
# sale_last6m_sum_div,
# sale_last12m_sum_div,
# sale_last2m_std_div,
# sale_last3m_std_div,
# sale_last6m_std_div,
# sale_last12m_std_div,
# sale_last2m_avg_div,
# sale_last3m_avg_div,
# sale_last6m_avg_div,
# sale_last12m_avg_div,
# max2m_div,
# max3m_div,
# max6m_div,
# max12m_div,
# min2m_div,
# min3m_div,
# min6m_div,
# min12m_div,
# lastyear_mom_div,
# spring_festival_div,
# produce_quantity_last1m_div,

# %%
sale_date,
province_id,
city_id,
class_id,
sale_quantity_add,
oil_price,
year,
month,
how_many_month_sale,
purchase_tax,
cnt_classid,
spring_festival,
total_sale_last1m_add,
total_last12m_sum_add,
sale_last1m_add,
sale_last12m_add,
sale_last2m_sum_add,
sale_last3m_sum_add,
sale_last6m_sum_add,
sale_last12m_sum_add,
sale_last2m_std_add,
sale_last3m_std_add,
sale_last6m_std_add,
sale_last12m_std_add,
sale_last2m_avg_add,
sale_last3m_avg_add,
sale_last6m_avg_add,
sale_last12m_avg_add,
max2m_add,
max3m_add,
max6m_add,
max12m_add,
min2m_add,
min3m_add,
min6m_add,
min12m_add,
lastyear_mom_add,
produce_quantity_last1m_add

# %%
sale_date,
province_id,
city_id,
class_id,
sale_quantity_minus,
oil_price,
year,
month,
how_many_month_sale,
purchase_tax,
cnt_classid,
spring_festival,
total_sale_last1m_minus,
total_last12m_sum_minus,
sale_last1m_minus,
sale_last12m_minus,
sale_last2m_sum_minus,
sale_last3m_sum_minus,
sale_last6m_sum_minus,
sale_last12m_sum_minus,
sale_last2m_std_minus,
sale_last3m_std_minus,
sale_last6m_std_minus,
sale_last12m_std_minus,
sale_last2m_avg_minus,
sale_last3m_avg_minus,
sale_last6m_avg_minus,
sale_last12m_avg_minus,
max2m_minus,
max3m_minus,
max6m_minus,
max12m_minus,
min2m_minus,
min3m_minus,
min6m_minus,
min12m_minus,
lastyear_mom_minus,
produce_quantity_last1m_minus,

# %%
sale_date,
province_id,
city_id,
class_id,
sale_quantity_mul,
oil_price,
year,
month,
how_many_month_sale,
purchase_tax,
cnt_classid,
spring_festival,
total_sale_last1m_mul,
total_last12m_sum_mul,
sale_last1m_mul,
sale_last12m_mul,
sale_last2m_sum_mul,
sale_last3m_sum_mul,
sale_last6m_sum_mul,
sale_last12m_sum_mul,
sale_last2m_std_mul,
sale_last3m_std_mul,
sale_last6m_std_mul,
sale_last12m_std_mul,
sale_last2m_avg_mul,
sale_last3m_avg_mul,
sale_last6m_avg_mul,
sale_last12m_avg_mul,
max2m_mul,
max3m_mul,
max6m_mul,
max12m_mul,
min2m_mul,
min3m_mul,
min6m_mul,
min12m_mul,
lastyear_mom_mul,
produce_quantity_last1m_mul,

# %%
sale_date,
province_id,
city_id,
class_id,
sale_quantity_div,
oil_price,
year,
month,
how_many_month_sale,
purchase_tax,
cnt_classid,
spring_festival,
total_sale_last1m_div,
total_last12m_sum_div,
sale_last1m_div,
sale_last12m_div,
sale_last2m_sum_div,
sale_last3m_sum_div,
sale_last6m_sum_div,
sale_last12m_sum_div,
sale_last2m_std_div,
sale_last3m_std_div,
sale_last6m_std_div,
sale_last12m_std_div,
sale_last2m_avg_div,
sale_last3m_avg_div,
sale_last6m_avg_div,
sale_last12m_avg_div,
max2m_div,
max3m_div,
max6m_div,
max12m_div,
min2m_div,
min3m_div,
min6m_div,
min12m_div,
lastyear_mom_div,
produce_quantity_last1m_div,

# %%
list_num=[201201,201202,201203,201204,201205,201206,201207,201208,201209,201210,201211,201212,201301,201302,201303,201304,201305,201306,201307,201308,201309,201310,201311,201312,201401,201402,201403,201404,201405,201406,201407,201408,201409,201410,201411,201412,201501,201502,201503,201504,201505,201506,201507,201508,201509,201510,201511,201512,201601,201602,201603,201604,201605,201606,201607,201608,201609,201610,201611,201612,201701,201702,201703,201704,201705,201706,201707,201708,201709,201710,201711,201712]

# %%
for i in range(len(list_num)):
    if (i+1)%2==0:
        print(str(list_num[i])+',')
# Out:
# 201202,
# 201204,
# 201206,
# 201208,
# 201210,
# 201212,
# 201302,
# 201304,
# 201306,
# 201308,
# 201310,
# 201312,
# 201402,
# 201404,
# 201406,
# 201408,
# 201410,
# 201412,
# 201502,
# 201504,
# 201506,
# 201508,
# 201510,
# 201512,
# 201602,
# 201604,
# 201606,
# 201608,
# 201610,

# %%
ss=''
for i in range(len(list_num)):
    if (i+1)%2==0:
        ss=ss+str(list_num[i])+','
print(ss)
# Out:
# 201202,201204,201206,201208,201210,201212,201302,201304,201306,201308,201310,201312,201402,201404,201406,201408,201410,201412,201502,201504,201506,201508,201510,201512,201602,201604,201606,201608,201610,201612,201702,201704,201706,201708,201710,201712,

# %%
ss=''
for i in range(len(list_num)):
    if i%2==0:
        ss=ss+str(list_num[i])+','
print(ss)
# Out:
# 201201,201203,201205,201207,201209,201211,201301,201303,201305,201307,201309,201311,201401,201403,201405,201407,201409,201411,201501,201503,201505,201507,201509,201511,201601,201603,201605,201607,201609,201611,201701,201703,201705,201707,201709,201711,

# %%
ls
# Out:
# S2_feature_month_name.csv
# S2_feature_name.csv
# S2_province_sale_quantity.xlsx
# S2训练数据表现.xlsx
# S2全国各月产量销量表.csv
# result_180223_baseline*0.7_lightGBM*0.3.csv
# result_180224_baseline*0.5_lightGBM*0.3_lstm*0.2.csv
# result_180224_baseline*0.5_lightGBM*0.5.csv
# result_180226_GBDT.csv
# result_180226_gbdt*0.5_xgb*0.5.csv
# result_180226_gbdt_big_quantity*1.5.csv
# result_20180209_xgboost-allfeatures*0.5-baseline*0.5*1.1.csv
# result_20180209_xgboost-allfeatures.csv
# result_woody20180204_1.csv
# result_woody20180204_2.csv
# result_woody20180206_1
# result_woody20180206_1.csv
# s2_woody_lichuan0307_feature_13_time_window_head.csv
# stuff_woody_0310_max_min_window.csv
# stuff_woody_0310_max_min_window.xlsx
# ycc_sales_lichuan0307_feature_14_max_min.csv
# ycc_sales_lichuan0307_feature_16_produce_quantity.csv
# ycc_sales_lichuan0307_feature_3_change_double.csv
# ycc_sales_lichuan0307_trainset_1_time_window_head.csv
# ycc_sales_lichuan0307_traintest_1_time_window.csv
# ...

# %%
data7=pd.read_csv('ycc_sales_lichuan0314_feature_16_produce_quantity_minus.csv')

# %%
x_col_name(data7,'a')
# Out:
# a.sale_date,
# a.province_id,
# a.city_id,
# a.class_id,
# a.sale_quantity,
# a.oil_price,
# a.total_sale_last1m,
# a.total_last12m_sum,
# a.sale_last1m,
# a.sale_last12m,
# a.cnt_classid,
# a.year,
# a.month,
# a.how_many_month_sale,
# a.purchase_tax,
# a.sale_last2m_sum,
# a.sale_last3m_sum,
# a.sale_last6m_sum,
# a.sale_last12m_sum,
# a.sale_last2m_std,
# a.sale_last3m_std,
# a.sale_last6m_std,
# a.sale_last12m_std,
# a.sale_last2m_avg,
# a.sale_last3m_avg,
# a.sale_last6m_avg,
# a.sale_last12m_avg,
# a.max2m,
# a.max3m,
# a.max6m,
# a.max12m,
# a.min2m,
# a.min3m,
# a.min6m,
# a.min12m,
# a.spring_festival,
# a.produce_quantity_last1m,

# %%
x_col_name(data2,'b')
# Out:
# b.class_id,
# b.power_max,
# b.power_min,
# b.power_avg,
# b.car_length_max,
# b.car_length_min,
# b.car_length_avg,
# b.car_width_max,
# b.car_width_min,
# b.car_width_avg,
# b.car_height_max,
# b.car_height_min,
# b.car_height_avg,
# b.total_quality_max,
# b.total_quality_min,
# b.total_quality_avg,
# b.equipment_quality_max,
# b.equipment_quality_min,
# b.equipment_quality_avg,
# b.wheelbase_max,
# b.wheelbase_min,
# b.wheelbase_avg,
# b.front_track_max,
# b.front_track_min,
# b.front_track_avg,
# b.rear_track_max,
# b.rear_track_min,
# b.rear_track_avg,
# b.price_level_max,
# b.price_level_min,
# b.price_level_avg,
# b.displacement_max,
# b.displacement_min,
# b.displacement_avg,
# b.rated_passenger_max,
# b.rated_passenger_min,
# b.rated_passenger_avg,
# b.brand_id_15,
# b.brand_id_18,
# b.brand_id_21,
# b.brand_id_27,
# b.brand_id_30,
# b.brand_id_36,
# b.brand_id_39,
# b.brand_id_42,
# b.brand_id_48,
# b.brand_id_57,
# b.brand_id_60,
# b.brand_id_63,
# b.brand_id_66,
# ...

# %%
-- ycc_woody_0314_mock_B_strategy_three_add_0_1202_1710_train
-- ycc_woody_0314_mock_B_strategy_three_add_0_1202_1712_train
-- ycc_woody_0314_mock_B_strategy_three_add_0_1302_1710_train
-- ycc_woody_0314_mock_B_strategy_three_add_0_1302_1712_train

# %%
-- ycc_woody_0314_mock_B_strategy_three_minus_0_1202_1710_train
-- ycc_woody_0314_mock_B_strategy_three_minus_0_1202_1712_train
-- ycc_woody_0314_mock_B_strategy_three_minus_0_1302_1710_train
-- ycc_woody_0314_mock_B_strategy_three_minus_0_1302_1712_train

# %%
ycc_woody_0314_mock_B_strategy_three_add_1802_test
ycc_woody_0314_mock_B_strategy_three_add_0_1202_1710_train 
ycc_woody_0314_mock_B_strategy_three_add_0_1202_1712_train
ycc_woody_0314_mock_B_strategy_three_add_0_1302_1710_train
ycc_woody_0314_mock_B_strategy_three_add_0_1302_1712_train
